# %% [markdown]
# # IndicBART Hindi Grammar Error Correction - Complete Training
#
# This notebook provides a complete solution for training IndicBART on Hindi grammar error correction using the combined dataset.
#
# **Features:**
# - Proper MBART tokenization (fixes token_type_ids error)
# - Large dataset training (10k+ samples)
# - Fixed generation parameters (no repetition loops)
# - Early stopping and best model saving
# - Comprehensive evaluation on dev set
#
# **Dataset:** `Hindi/combined_test_dataset.csv`

# %%
# Install and import required packages
import subprocess
import sys

# Install packages if needed
required_packages = [
    'torch',
    'transformers',
    'datasets',
    'pandas', 
    'numpy',
    'scikit-learn',
    'tqdm'
]

for package in required_packages:
    try:
        __import__(package)
    except ImportError:
        print(f"Installing {package}...")
        subprocess.check_call([sys.executable, '-m', 'pip', 'install', package])

print("All packages ready!")
# Out:
# Installing scikit-learn...
# All packages ready!
# All packages ready!

# %%
# Core imports
import torch
import pandas as pd
import numpy as np
from pathlib import Path
from sklearn.model_selection import train_test_split
from tqdm import tqdm
import json
import warnings
warnings.filterwarnings('ignore')

# Transformers imports
from transformers import (
    AutoModelForSeq2SeqLM,
    AutoTokenizer,
    TrainingArguments,
    Trainer,
    DataCollatorForSeq2Seq,
    EarlyStoppingCallback
)
from datasets import Dataset
import transformers

print("Libraries imported successfully!")
print(f"PyTorch version: {torch.__version__}")
print(f"Transformers version: {transformers.__version__}")
print(f"CUDA available: {torch.cuda.is_available()}")

if torch.cuda.is_available():
    print(f"GPU: {torch.cuda.get_device_name()}")
    print(f"GPU Memory: {torch.cuda.get_device_properties(0).total_memory / 1024**3:.1f} GB")
# Out:
# Libraries imported successfully!
# PyTorch version: 2.8.0+cu129
# Transformers version: 4.56.2
# CUDA available: True
# GPU: NVIDIA GeForce RTX 4050 Laptop GPU
# GPU Memory: 6.0 GB

# %%
# Configuration
CONFIG = {
    # Model settings
    'model_name': 'ai4bharat/IndicBART',
    'max_length': 128,
    'device': 'cuda' if torch.cuda.is_available() else 'cpu',
    
    # Data settings
    'dataset_path': 'Hindi/combined_test_dataset.csv',
    'test_size': 0.2,  # 20% for dev set
    'random_seed': 42,
    
    # Training settings
    'output_dir': './indicbart-hindi-final',
    'num_epochs': 50,
    'train_batch_size': 1,  # Reduced for stability
    'eval_batch_size': 1,   # Reduced for stability
    'gradient_accumulation_steps': 16,  # Increased to maintain effective batch size = 1 * 16 = 16
    'learning_rate': 1e-6,  # Conservative learning rate
    'warmup_ratio': 0.1,
    'weight_decay': 0.01,
    'max_grad_norm': 1.0,
    
    # Evaluation settings
    'eval_steps': 500,
    'save_steps': 500,
    'logging_steps': 100,
    'save_total_limit': 3,
    'early_stopping_patience': 3,
    
    # Generation settings (fixes repetition issues)
    'generation_config': {
        'max_new_tokens': 64,
        'min_new_tokens': 1,
        'num_beams': 4,
        'early_stopping': True,
        'repetition_penalty': 1.5,
        'no_repeat_ngram_size': 3,
        'length_penalty': 0.8,
        'do_sample': False,
    }
}

print("Configuration:")
for key, value in CONFIG.items():
    if key != 'generation_config':
        print(f"   {key}: {value}")

print(f"\nGeneration Config:")
for key, value in CONFIG['generation_config'].items():
    print(f"   {key}: {value}")
# Out:
# Configuration:
#    model_name: ai4bharat/IndicBART
#    max_length: 128
#    device: cuda
#    dataset_path: Hindi/combined_test_dataset.csv
#    test_size: 0.2
#    random_seed: 42
#    output_dir: ./indicbart-hindi-final
#    num_epochs: 50
#    train_batch_size: 1
#    eval_batch_size: 1
#    gradient_accumulation_steps: 16
#    learning_rate: 1e-06
#    warmup_ratio: 0.1
#    weight_decay: 0.01
#    max_grad_norm: 1.0
#    eval_steps: 500
#    save_steps: 500
#    logging_steps: 100
#    save_total_limit: 3
#    early_stopping_patience: 3
#
# Generation Config:
#    max_new_tokens: 64
#    min_new_tokens: 1
#    num_beams: 4
#    early_stopping: True
#    repetition_penalty: 1.5
#    no_repeat_ngram_size: 3
#    length_penalty: 0.8
#    do_sample: False

# %%
# Load and prepare dataset
print("Loading dataset...")

dataset_path = Path(CONFIG['dataset_path'])
if not dataset_path.exists():
    raise FileNotFoundError(f"Dataset not found: {dataset_path}")

# Load dataset
df = pd.read_csv(dataset_path, encoding='utf-8')
print(f"Dataset loaded: {df.shape}")
print(f"File size: {dataset_path.stat().st_size / (1024**2):.1f} MB")
print(f"Columns: {list(df.columns)}")

# Handle column names
if 'input' in df.columns and 'output' in df.columns:
    input_col, output_col = 'input', 'output'
elif len(df.columns) >= 2:
    input_col, output_col = df.columns[0], df.columns[1]
    print(f"Using columns: '{input_col}' -> '{output_col}'")
else:
    raise ValueError("Cannot identify input/output columns")

# Clean data
print(f"\nCleaning data...")
original_size = len(df)

# Remove nulls and empty strings
df = df.dropna(subset=[input_col, output_col])
df[input_col] = df[input_col].astype(str).str.strip()
df[output_col] = df[output_col].astype(str).str.strip()
df = df[(df[input_col] != '') & (df[output_col] != '')]

# Filter by length (5-200 characters)
df = df[
    (df[input_col].str.len() >= 5) & (df[input_col].str.len() <= 200) &
    (df[output_col].str.len() >= 5) & (df[output_col].str.len() <= 200)
]

print(f"   Original: {original_size:,} samples")
print(f"   Cleaned: {len(df):,} samples")
print(f"   Removed: {original_size - len(df):,} samples")

# Rename columns
df_clean = df[[input_col, output_col]].copy()
df_clean.columns = ['input_text', 'output_text']

# Analyze data composition
identical = (df_clean['input_text'] == df_clean['output_text']).sum()
corrections = len(df_clean) - identical

print(f"\nData composition:")
print(f"   Identity pairs: {identical:,} ({identical/len(df_clean)*100:.1f}%)")
print(f"   Corrections: {corrections:,} ({corrections/len(df_clean)*100:.1f}%)")

# Show examples
print(f"\nSample corrections:")
correction_samples = df_clean[df_clean['input_text'] != df_clean['output_text']].head(3)
for i, (_, row) in enumerate(correction_samples.iterrows(), 1):
    print(f"  {i}. Input:  {row['input_text'][:80]}...")
    print(f"     Output: {row['output_text'][:80]}...")
    print()
# Out:
# Loading dataset...
# Dataset loaded: (10599, 3)
# File size: 14.7 MB
# Columns: ['Input sentence', 'Output sentence', 'Unnamed: 2']
# Using columns: 'Input sentence' -> 'Output sentence'
#
# Cleaning data...
#    Original: 10,599 samples
#    Cleaned: 5,268 samples
#    Removed: 5,331 samples
#
# Data composition:
#    Identity pairs: 2,442 (46.4%)
#    Corrections: 2,826 (53.6%)
#
# Sample corrections:
#   1. Input:  ये केवल किताबी ज्ञान अर्जन तक ही सिमित नहीं है।...
#      Output: ये केवल किताबी ज्ञान अर्जन तक ही सीमित नहीं है।...
#
#   2. Input:  जैसे - व्यावहारिक शिक्षा, किताबी शिक्षा अथवा अध्यामित्क शिक्षा...
#      Output: जैसे - व्यावहारिक शिक्षा, किताबी शिक्षा अथवा आध्यात्मिक शिक्षा ।...
#
#   3. Input:  वहाँ  अचार्य होते थे शिक्षक के स्थान पे।...
#      Output: वहाँ  अचार्य होते थे शिक्षक के स्थान पर।...

# %%
# Create train/dev splits
print("Creating train/dev splits...")

# Stratified split to maintain correction ratio
df_clean['is_correction'] = (df_clean['input_text'] != df_clean['output_text']).astype(int)

train_df, dev_df = train_test_split(
    df_clean,
    test_size=CONFIG['test_size'],
    random_state=CONFIG['random_seed'],
    stratify=df_clean['is_correction']
)

# Remove helper column
train_df = train_df[['input_text', 'output_text']].reset_index(drop=True)
dev_df = dev_df[['input_text', 'output_text']].reset_index(drop=True)

print(f"Split complete:")
print(f"   Train: {len(train_df):,} samples")
print(f"   Dev: {len(dev_df):,} samples")

# Verify split distribution
train_corrections = (train_df['input_text'] != train_df['output_text']).sum()
dev_corrections = (dev_df['input_text'] != dev_df['output_text']).sum()

print(f"\nDistribution maintained:")
print(f"   Train corrections: {train_corrections:,}/{len(train_df):,} ({train_corrections/len(train_df)*100:.1f}%)")
print(f"   Dev corrections: {dev_corrections:,}/{len(dev_df):,} ({dev_corrections/len(dev_df)*100:.1f}%)")
# Out:
# Creating train/dev splits...
# Split complete:
#    Train: 4,214 samples
#    Dev: 1,054 samples
#
# Distribution maintained:
#    Train corrections: 2,261/4,214 (53.7%)
#    Dev corrections: 565/1,054 (53.6%)

# %%
# Load model and tokenizer
print(f"Loading IndicBART model and tokenizer...")

# Clear GPU memory
if torch.cuda.is_available():
    torch.cuda.empty_cache()

# Load tokenizer
tokenizer = AutoTokenizer.from_pretrained(CONFIG['model_name'])
print(f"Tokenizer loaded: {type(tokenizer).__name__}")
print(f"   Vocab size: {len(tokenizer):,}")

# Load model
model = AutoModelForSeq2SeqLM.from_pretrained(
    CONFIG['model_name'],
    torch_dtype=torch.float32  # Use float32 for stability
)

print(f"Model loaded: {type(model).__name__}")
print(f"   Parameters: {sum(p.numel() for p in model.parameters()) / 1e6:.1f}M")
print(f"   Device: {CONFIG['device']}")

# Move model to device
model = model.to(CONFIG['device'])

# Fix tokenizer padding
if tokenizer.pad_token is None:
    tokenizer.pad_token = tokenizer.eos_token
    model.config.pad_token_id = tokenizer.eos_token_id
    print(f"Set pad_token to eos_token")

print(f"\nModel ready for training!")

if CONFIG['device'] == 'cuda':
    print(f"GPU memory: {torch.cuda.memory_allocated() / 1024**3:.1f} GB allocated")
    print(f"GPU memory: {torch.cuda.memory_reserved() / 1024**3:.1f} GB reserved")
# Out:
# Loading IndicBART model and tokenizer...
# Tokenizer loaded: AlbertTokenizerFast
#    Vocab size: 64,014
# Tokenizer loaded: AlbertTokenizerFast
#    Vocab size: 64,014
# Model loaded: MBartForConditionalGeneration
#    Parameters: 244.0M
#    Device: cuda
# Model loaded: MBartForConditionalGeneration
#    Parameters: 244.0M
#    Device: cuda
#
# Model ready for training!
# GPU memory: 3.7 GB allocated
# GPU memory: 3.8 GB reserved
#
# Model ready for training!
# GPU memory: 3.7 GB allocated
# GPU memory: 3.8 GB reserved

# %%
# Tokenization function (MBART compatible)
def tokenize_function(examples):
    """Tokenize examples for MBART - handles token_type_ids properly"""
    # Create input with task prefix
    inputs = [f"सुधारें: {text}" for text in examples['input_text']]
    targets = examples['output_text']
    
    # Tokenize inputs (CRITICAL: return_token_type_ids=False for MBART)
    model_inputs = tokenizer(
        inputs,
        max_length=CONFIG['max_length'],
        truncation=True,
        padding=False,  # Dynamic padding during training
        return_token_type_ids=False  # MBART doesn't use token_type_ids!
    )
    
    # Tokenize targets (CRITICAL: return_token_type_ids=False for MBART)
    with tokenizer.as_target_tokenizer():
        labels = tokenizer(
            targets,
            max_length=CONFIG['max_length'],
            truncation=True,
            padding=False,
            return_token_type_ids=False  # MBART doesn't use token_type_ids!
        )
    
    # Set labels
    model_inputs["labels"] = labels["input_ids"]
    
    # Double-check: remove any token_type_ids that might sneak in
    model_inputs.pop("token_type_ids", None)
    
    return model_inputs

print("Tokenization function created (MBART compatible)")

# Test tokenization
print("\nTesting tokenization...")
test_example = {
    'input_text': [train_df['input_text'].iloc[0]],
    'output_text': [train_df['output_text'].iloc[0]]
}

test_result = tokenize_function(test_example)
print(f"Tokenization test passed!")
print(f"   Keys: {list(test_result.keys())}")
print(f"   Input IDs length: {len(test_result['input_ids'][0])}")
print(f"   Labels length: {len(test_result['labels'][0])}")

# Verify no token_type_ids
if 'token_type_ids' in test_result:
    raise ValueError("token_type_ids found in tokenized output! This will cause MBART error.")
else:
    print(f"No token_type_ids found - MBART compatible!")
# Out:
# Tokenization function created (MBART compatible)
#
# Testing tokenization...
# Tokenization test passed!
#    Keys: ['input_ids', 'attention_mask', 'labels']
#    Input IDs length: 52
#    Labels length: 49
# No token_type_ids found - MBART compatible!

# %%
# Create datasets
print("Creating datasets...")

# Convert to HuggingFace datasets
train_dataset = Dataset.from_pandas(train_df)
dev_dataset = Dataset.from_pandas(dev_df)

print(f"   Created train dataset: {len(train_dataset):,} samples")
print(f"   Created dev dataset: {len(dev_dataset):,} samples")

# Tokenize datasets
print(f"\nTokenizing datasets...")

train_tokenized = train_dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=train_dataset.column_names,
    desc="Tokenizing train"
)

dev_tokenized = dev_dataset.map(
    tokenize_function,
    batched=True,
    remove_columns=dev_dataset.column_names,
    desc="Tokenizing dev"
)

print(f"Tokenization complete!")
print(f"   Train tokenized: {len(train_tokenized):,} samples")
print(f"   Dev tokenized: {len(dev_tokenized):,} samples")

# Show tokenized example
print(f"\nTokenized sample:")
sample = train_tokenized[0]
print(f"   Keys: {list(sample.keys())}")
print(f"   Input IDs: {sample['input_ids'][:10]}... (length: {len(sample['input_ids'])})")
print(f"   Labels: {sample['labels'][:10]}... (length: {len(sample['labels'])})")

# Verify no token_type_ids in tokenized datasets
if 'token_type_ids' in sample:
    raise ValueError("token_type_ids found in tokenized dataset!")
else:
    print(f"Tokenized datasets are MBART compatible!")
# Out:
# Creating datasets...
#    Created train dataset: 4,214 samples
#    Created dev dataset: 1,054 samples
#
# Tokenizing datasets...
# Tokenizing train: 100%|██████████| 4214/4214 [00:00<00:00, 12969.53 examples/s]
# Tokenizing train: 100%|██████████| 4214/4214 [00:00<00:00, 12969.53 examples/s]
# Tokenizing dev: 100%|██████████| 1054/1054 [00:00<00:00, 17050.48 examples/s]
# Tokenization complete!
#    Train tokenized: 4,214 samples
#    Dev tokenized: 1,054 samples
#
# Tokenized sample:
#    Keys: ['input_ids', 'attention_mask', 'labels']
#    Input IDs: [2, 2656, 1968, 53, 593, 2135, 13, 8857, 5681, 4706]... (length: 52)
#    Labels: [2, 593, 2135, 13, 8857, 5681, 4706, 903, 2284, 12383]... (length: 49)
# Tokenized datasets are MBART compatible!

# %%
# Create data collator
data_collator = DataCollatorForSeq2Seq(
    tokenizer=tokenizer,
    model=model,
    padding=True,
    return_tensors="pt"
)

print(f"Data collator created: {type(data_collator).__name__}")

# Test data collator
print(f"\nTesting data collator...")
test_batch = [train_tokenized[i] for i in range(2)]  # Get 2 samples
collated_batch = data_collator(test_batch)

print(f"Data collator test passed!")
print(f"   Batch keys: {list(collated_batch.keys())}")
print(f"   Input IDs shape: {collated_batch['input_ids'].shape}")
print(f"   Labels shape: {collated_batch['labels'].shape}")

# Final check: no token_type_ids in collated batch
if 'token_type_ids' in collated_batch:
    raise ValueError("token_type_ids found in collated batch!")
else:
    print(f"Collated batch is MBART compatible!")
# Out:
# Data collator created: DataCollatorForSeq2Seq
#
# Testing data collator...
# Data collator test passed!
#    Batch keys: ['input_ids', 'attention_mask', 'labels', 'decoder_input_ids']
#    Input IDs shape: torch.Size([2, 52])
#    Labels shape: torch.Size([2, 49])
# Collated batch is MBART compatible!

# %%
# Training arguments
training_args = TrainingArguments(
    # Output and logging
    output_dir=CONFIG['output_dir'],
    logging_dir=f"{CONFIG['output_dir']}/logs",
    logging_steps=CONFIG['logging_steps'],
    report_to=None,  # Disable wandb/tensorboard
    
    # Training schedule
    num_train_epochs=CONFIG['num_epochs'],
    per_device_train_batch_size=CONFIG['train_batch_size'],
    per_device_eval_batch_size=CONFIG['eval_batch_size'],
    gradient_accumulation_steps=CONFIG['gradient_accumulation_steps'],
    
    # Optimization
    learning_rate=CONFIG['learning_rate'],
    warmup_ratio=CONFIG['warmup_ratio'],
    weight_decay=CONFIG['weight_decay'],
    max_grad_norm=CONFIG['max_grad_norm'],
    
    # Evaluation and saving
    eval_strategy="steps",
    eval_steps=CONFIG['eval_steps'],
    save_strategy="steps",
    save_steps=CONFIG['save_steps'],
    save_total_limit=CONFIG['save_total_limit'],
    load_best_model_at_end=True,
    metric_for_best_model="eval_loss",
    greater_is_better=False,
    
    # Performance
    fp16=False,  # Disable FP16 to avoid gradient unscaling issues
    dataloader_pin_memory=False,
    dataloader_num_workers=0,
    remove_unused_columns=True,  # Important: removes token_type_ids
    
    # Reproducibility
    seed=CONFIG['random_seed'],
    data_seed=CONFIG['random_seed'],
)

print(f"Training arguments created:")
print(f"   Effective batch size: {training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps}")
print(f"   Learning rate: {training_args.learning_rate}")
print(f"   Epochs: {training_args.num_train_epochs}")
print(f"   Output: {training_args.output_dir}")
print(f"   Best model metric: {training_args.metric_for_best_model}")
print(f"   FP16: {training_args.fp16}")
print(f"   Remove unused columns: {training_args.remove_unused_columns}")
# Out:
# Training arguments created:
#    Effective batch size: 16
#    Learning rate: 1e-06
#    Epochs: 50
#    Output: ./indicbart-hindi-final
#    Best model metric: eval_loss
#    FP16: False
#    Remove unused columns: True

# %%
# Create trainer
trainer = Trainer(
    model=model,
    args=training_args,
    train_dataset=train_tokenized,
    eval_dataset=dev_tokenized,
    tokenizer=tokenizer,
    data_collator=data_collator,
    callbacks=[
        EarlyStoppingCallback(early_stopping_patience=CONFIG['early_stopping_patience'])
    ]
)

print(f"Trainer created successfully!")
print(f"   Train samples: {len(train_tokenized):,}")
print(f"   Dev samples: {len(dev_tokenized):,}")
print(f"   Early stopping patience: {CONFIG['early_stopping_patience']}")
print(f"   Model will be saved every {CONFIG['save_steps']} steps")

# Estimate training time
steps_per_epoch = len(train_tokenized) // (training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps)
total_steps = steps_per_epoch * training_args.num_train_epochs
print(f"\nTraining estimates:")
print(f"   Steps per epoch: {steps_per_epoch}")
print(f"   Total steps: {total_steps}")
print(f"   Estimated time: ~{total_steps * 2 / 3600:.1f} hours (assuming 2 sec/step)")
# Out:
# Trainer created successfully!
#    Train samples: 4,214
#    Dev samples: 1,054
#    Early stopping patience: 3
#    Model will be saved every 500 steps
#
# Training estimates:
#    Steps per epoch: 263
#    Total steps: 13150
#    Estimated time: ~7.3 hours (assuming 2 sec/step)

# %%
# Start training with complete FP16 disable
print(f"Starting IndicBART training...")
print(f"="*60)
print(f"Dataset: {len(train_tokenized):,} train + {len(dev_tokenized):,} dev samples")
print(f"Model: {CONFIG['model_name']}")
print(f"Effective batch size: {training_args.per_device_train_batch_size * training_args.gradient_accumulation_steps}")
print(f"Learning rate: {training_args.learning_rate}")
print(f"Epochs: {training_args.num_train_epochs}")
print(f"Output: {training_args.output_dir}")
print(f"="*60)

try:
    # Clear any previous training state
    if CONFIG['device'] == 'cuda':
        torch.cuda.empty_cache()
    
    # Start training
    training_output = trainer.train()
    
    print(f"\nTRAINING COMPLETED SUCCESSFULLY!")
    print(f"Final training loss: {training_output.training_loss:.4f}")
    
    # Save final model
    print(f"\nSaving final model...")
    trainer.save_model()
    tokenizer.save_pretrained(CONFIG['output_dir'])
    
    # Save configuration
    with open(f"{CONFIG['output_dir']}/config.json", 'w') as f:
        json.dump(CONFIG, f, indent=2, default=str)
    
    print(f"Model saved to: {CONFIG['output_dir']}")
    
    # Final evaluation
    print(f"\nFinal evaluation on dev set...")
    final_eval = trainer.evaluate()
    print(f"Final evaluation loss: {final_eval['eval_loss']:.4f}")
    print(f"Evaluation runtime: {final_eval['eval_runtime']:.1f} seconds")
    print(f"Samples per second: {final_eval['eval_samples_per_second']:.1f}")
    
    # Store results in globals
    globals()['trained_model'] = model
    globals()['trained_tokenizer'] = tokenizer
    globals()['training_results'] = training_output
    globals()['final_eval_results'] = final_eval
    globals()['training_completed'] = True
    
    print(f"\nTraining successfully completed!")
    
except Exception as e:
    print(f"\nTraining failed with error:")
    print(f"Error: {str(e)}")
    print(f"\nDebugging information:")
    print(f"   Model dtype: {model.dtype}")
    print(f"   Training args fp16: {training_args.fp16}")
    print(f"   PyTorch autocast enabled: {torch.is_autocast_enabled()}")
    
    # Show memory info if CUDA
    if CONFIG['device'] == 'cuda':
        print(f"\nGPU Memory Status:")
        print(f"   Allocated: {torch.cuda.memory_allocated() / 1024**3:.1f} GB")
        print(f"   Reserved: {torch.cuda.memory_reserved() / 1024**3:.1f} GB")
    
    raise
# Out:
# The tokenizer has new PAD/BOS/EOS tokens that differ from the model config and generation config. The model config and generation config were aligned accordingly, being updated with the tokenizer's values. Updated tokens: {'eos_token_id': 3, 'bos_token_id': 2}.
# Starting IndicBART training...
# ============================================================
# Dataset: 4,214 train + 1,054 dev samples
# Model: ai4bharat/IndicBART
# Effective batch size: 16
# Learning rate: 1e-06
# Epochs: 50
# Output: ./indicbart-hindi-final
# ============================================================
#
# Training failed with error:
# Error: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# Debugging information:
#    Model dtype: torch.float32
#    Training args fp16: False
#    PyTorch autocast enabled: False
#
# GPU Memory Status:
#    Allocated: 6.4 GB
#    Reserved: 6.5 GB
#
# Training failed with error:
# Error: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.
#
#
# Debugging information:
#    Model dtype: torch.float32
#    Training args fp16: False
#    PyTorch autocast enabled: False
#
# GPU Memory Status:
#    Allocated: 6.4 GB
#    Reserved: 6.5 GB
# ---------------------------------------------------------------------------
# AcceleratorError                          Traceback (most recent call last)
# Cell In[48], line 18
#      15     torch.cuda.empty_cache()
#      17 # Start training
# ---> 18 training_output = trainer.train()
#      20 print(f"\nTRAINING COMPLETED SUCCESSFULLY!")
#      21 print(f"Final training loss: {training_output.training_loss:.4f}")
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\transformers\trainer.py:2328, in Trainer.train(self, resume_from_checkpoint, trial, ignore_keys_for_eval, **kwargs)
#    2326         hf_hub_utils.enable_progress_bars()
#    2327 else:
# -> 2328     return inner_training_loop(
#    2329         args=args,
#    2330         resume_from_checkpoint=resume_from_checkpoint,
#    2331         trial=trial,
#    2332         ignore_keys_for_eval=ignore_keys_for_eval,
#    2333     )
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\transformers\trainer.py:2738, in Trainer._inner_training_loop(self, batch_size, args, resume_from_checkpoint, trial, ignore_keys_for_eval)
#    2735     context = implicit_replication
#    2737 with context():
# -> 2738     self.optimizer.step()
#    2740 self.control = self.callback_handler.on_optimizer_step(args, self.state, self.control)
#    2742 # get leaning rate before update
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\accelerate\optimizer.py:166, in AcceleratedOptimizer.step(self, closure)
#     163 if self.scaler is not None:
#     164     self.optimizer.step = self._optimizer_patched_step_method
# --> 166     self.scaler.step(self.optimizer, closure)
#     167     self.scaler.update()
#     169     if not self._accelerate_step_called:
#     170         # If the optimizer step was skipped, gradient overflow was detected.
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\torch\amp\grad_scaler.py:451, in GradScaler.step(self, optimizer, *args, **kwargs)
#     445     optimizer.grad_scale = (  # type: ignore[attr-defined]
#     446         getattr(optimizer, "grad_scale", None)
#     447         if optimizer_state["stage"] == OptState.UNSCALED
#     448         else scaler * getattr(optimizer, "grad_scale", 1)
#     449     )
#     450     optimizer.found_inf = found_inf  # type: ignore[attr-defined]
# --> 451 retval = optimizer.step(*args, **kwargs_)
#     452 optimizer_state["stage"] = OptState.STEPPED
#     453 if not has_grad_scaler_kwarg:
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\accelerate\optimizer.py:211, in patch_optimizer_step.<locals>.patched_step(*args, **kwargs)
#     209 def patched_step(*args, **kwargs):
#     210     accelerated_optimizer._accelerate_step_called = True
# --> 211     return method(*args, **kwargs)
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\torch\optim\lr_scheduler.py:133, in LRScheduler.__init__.<locals>.patch_track_step_called.<locals>.wrap_step.<locals>.wrapper(*args, **kwargs)
#     131 opt = opt_ref()
#     132 opt._opt_called = True  # type: ignore[union-attr]
# --> 133 return func.__get__(opt, opt.__class__)(*args, **kwargs)
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\torch\optim\optimizer.py:516, in Optimizer.profile_hook_step.<locals>.wrapper(*args, **kwargs)
#     511         else:
#     512             raise RuntimeError(
#     513                 f"{func} must return None or a tuple of (new_args, new_kwargs), but got {result}."
#     514             )
# --> 516 out = func(*args, **kwargs)
#     517 self._optimizer_step_code()
#     519 # call optimizer step post hooks
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\torch\optim\optimizer.py:81, in _use_grad_for_differentiable.<locals>._use_grad(*args, **kwargs)
#      79     torch.set_grad_enabled(self.defaults["differentiable"])
#      80     torch._dynamo.graph_break()
# ---> 81     ret = func(*args, **kwargs)
#      82 finally:
#      83     torch._dynamo.graph_break()
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\torch\optim\adam.py:237, in Adam.step(self, closure)
#     234     state_steps: list[Tensor] = []
#     235     beta1, beta2 = group["betas"]
# --> 237     has_complex = self._init_group(
#     238         group,
#     239         params_with_grad,
#     240         grads,
#     241         exp_avgs,
#     242         exp_avg_sqs,
#     243         max_exp_avg_sqs,
#     244         state_steps,
#     245     )
#     247     adam(
#     248         params_with_grad,
#     249         grads,
#    (...)    268         decoupled_weight_decay=group["decoupled_weight_decay"],
#     269     )
#     271 return loss
#
# File d:\CODING\IndicGEC2025\.venv\Lib\site-packages\torch\optim\adam.py:177, in Adam._init_group(self, group, params_with_grad, grads, exp_avgs, exp_avg_sqs, max_exp_avg_sqs, state_steps)
#     167 state["step"] = (
#     168     torch.zeros(
#     169         (),
#    (...)    174     else torch.tensor(0.0, dtype=_get_scalar_dtype())
#     175 )
#     176 # Exponential moving average of gradient values
# --> 177 state["exp_avg"] = torch.zeros_like(
#     178     p, memory_format=torch.preserve_format
#     179 )
#     180 # Exponential moving average of squared gradient values
#     181 state["exp_avg_sq"] = torch.zeros_like(
#     182     p, memory_format=torch.preserve_format
#     183 )
#
# AcceleratorError: CUDA error: out of memory
# CUDA kernel errors might be asynchronously reported at some other API call, so the stacktrace below might be incorrect.
# For debugging consider passing CUDA_LAUNCH_BLOCKING=1
# Compile with `TORCH_USE_CUDA_DSA` to enable device-side assertions.

# %%
# Additional stability measures for training
print("Applying additional stability measures...")

# 1. Ensure model is in float32
if model.dtype != torch.float32:
    print(f"Converting model from {model.dtype} to float32...")
    model = model.float()

# 2. Disable gradient checkpointing if it exists
if hasattr(model.config, 'gradient_checkpointing'):
    model.config.gradient_checkpointing = False
    print("Disabled gradient checkpointing")

# 3. Ensure no autocast is active
torch.backends.cudnn.enabled = True
torch.backends.cudnn.benchmark = False

# 4. Clear any cached gradients
for param in model.parameters():
    param.grad = None

# 5. Memory cleanup
if CONFIG['device'] == 'cuda':
    torch.cuda.empty_cache()
    torch.cuda.synchronize()
    print(f"GPU memory after cleanup: {torch.cuda.memory_allocated() / 1024**3:.1f} GB allocated")

print("Stability measures applied!")
# Out:
# Applying additional stability measures...
# Disabled gradient checkpointing
# GPU memory after cleanup: 2.7 GB allocated
# Stability measures applied!
# GPU memory after cleanup: 2.7 GB allocated
# Stability measures applied!

# %%
# Force disable all mixed precision and FP16 components
print("Forcing complete FP16 disable...")

# 1. Disable autocast globally
torch.set_autocast_enabled(False)

# 2. Ensure no AMP (Automatic Mixed Precision) is used
import torch.cuda.amp as amp
torch.backends.cuda.matmul.allow_tf32 = False
torch.backends.cudnn.allow_tf32 = False

# 3. Clear any AMP state
if torch.cuda.is_available():
    # Clear any existing AMP scalers
    torch.cuda.empty_cache()

# 4. Verify model is completely in float32
print(f"Model dtype: {model.dtype}")
print(f"Model device: {next(model.parameters()).device}")

# 5. Check if any parameters are in float16
fp16_params = [name for name, param in model.named_parameters() if param.dtype == torch.float16]
if fp16_params:
    print(f"WARNING: Found {len(fp16_params)} FP16 parameters!")
    for name in fp16_params[:5]:  # Show first 5
        print(f"  - {name}")
else:
    print("All model parameters are in float32 ✓")

print("Complete FP16 disable applied!")
# Out:
# Forcing complete FP16 disable...
# Model dtype: torch.float32
# Model device: cuda:0
# All model parameters are in float32 ✓
# Complete FP16 disable applied!

# %%
# Final clean grammar correction function
def correct_hindi_grammar(text, max_length=None):
    """Correct Hindi grammar using the trained model with robust post-processing"""
    if max_length is None:
        max_length = CONFIG['max_length']
    
    # Clean input
    text = str(text).strip()
    if not text:
        return text
    
    # Create input with task prefix
    input_text = f"सुधारें: {text}"
    
    # Tokenize
    inputs = tokenizer(
        input_text,
        return_tensors="pt",
        max_length=max_length,
        truncation=True,
        padding=False
    )
    
    # Move to model device
    inputs = {k: v.to(model.device) for k, v in inputs.items()}
    
    # Generate with balanced parameters
    with torch.no_grad():
        try:
            outputs = model.generate(
                input_ids=inputs['input_ids'],
                attention_mask=inputs['attention_mask'],
                max_length=inputs['input_ids'].shape[1] + 15,  # Limited extension
                num_beams=1,  # Greedy for consistency
                do_sample=False,
                repetition_penalty=5.0,  # High penalty for repetition
                eos_token_id=tokenizer.eos_token_id,
                pad_token_id=tokenizer.pad_token_id
            )
        except Exception as e:
            print(f"Generation failed: {str(e)}")
            return text
    
    # Decode result
    result = tokenizer.decode(outputs[0], skip_special_tokens=True)
    
    # Remove task prefix
    if result.startswith("सुधारें: "):
        result = result[8:].strip()
    
    # Aggressive cleaning of problematic output
    result = result.replace("[CLS]", "").replace("[SEP]", "").replace("[MASK]", "")
    result = result.replace("|", "").replace("/", "")
    
    # Split into words and clean
    words = result.split()
    
    # Remove obvious repetitions and clean words
    cleaned_words = []
    for word in words:
        # Skip very short or problematic words
        if len(word) < 1 or word in ["और", "एक", "है", "में", "का", "के", "की", "को", "से", "पर"] and len(cleaned_words) > 3:
            continue
        # Avoid repetition
        if not cleaned_words or word != cleaned_words[-1]:
            cleaned_words.append(word)
    
    # Reconstruct result
    result = " ".join(cleaned_words)
    
    # Final validation
    if (not result or 
        len(result) < 3 or 
        len(result.split()) > len(text.split()) * 2 or
        result == text):
        return text
    
    return result.strip()

print(f"Final clean grammar correction function created!")
print(f"   Includes robust post-processing and validation")
# Out:
# Model's generation config:
#    GenerationConfig {
#   "bos_token_id": 2,
#   "eos_token_id": [
#     3,
#     64001
#   ],
#   "forced_eos_token_id": 2,
#   "pad_token_id": 0
# }
#
#
# Tokenizer special tokens:
#    pad_token_id: 0
#    eos_token_id: 3
#    bos_token_id: 2
#    unk_token_id: 1
#
# Grammar correction function created with debugging!

# %%
# Test the trained model
print(f"Testing the trained model...")
print(f"="*50)

# Test sentences with various Hindi grammar errors
test_sentences = [
    "मैं कल दिल्ली जाऊगा",           # Missing anusvara (should be जाऊंगा)
    "वो स्कूल गया हैं",              # Verb agreement (should be गया है)
    "राम और श्याम खेल रहा है",         # Plural subject (should be खेल रहे हैं)
    "मुझे यह किताब पसंद हैं",         # Agreement error (should be पसंद है)
    "बच्चे पार्क में खेल रहे हैं",       # Correct sentence
    "उसके पास बहुत पैसा हैं",         # Agreement error (should be पैसा है)
    "हम सब मिलकर काम करेगे",         # Correct sentence
    "तुम कहा जा रहे हो",            # Wrong interrogative (should be कहाँ)
]

print(f"Test Results:")
print(f"-" * 80)

for i, sentence in enumerate(test_sentences, 1):
    try:
        corrected = correct_hindi_grammar(sentence)
        
        # Determine if changed
        changed = sentence.strip() != corrected.strip()
        status_icon = "CHANGED" if changed else "UNCHANGED"
        
        print(f"\n{i:2d}. {status_icon}")
        print(f"     Original:  {sentence}")
        print(f"     Corrected: {corrected}")
        
        # If changed, show what was corrected
        if changed:
            print(f"     -> Correction applied")
        
    except Exception as e:
        print(f"\n{i:2d}. ERROR")
        print(f"     Original: {sentence}")
        print(f"     Error: {str(e)[:60]}...")

print(f"\n" + "="*50)
print(f"Model testing completed!")
# Out:
# Testing the trained model...
# ==================================================
# Test Results:
# --------------------------------------------------------------------------------
#
#  1. CHANGED
#      Original:  मैं कल दिल्ली जाऊगा
#      Corrected: [CLS] मुझे कल दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा कोई कल दिल्ली जाऊगा | | | | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | | दिल्ली जाऊगा | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | दिल्ली जाऊगा[CLS]
#      -> Correction applied
#
#  1. CHANGED
#      Original:  मैं कल दिल्ली जाऊगा
#      Corrected: [CLS] मुझे कल दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा कोई कल दिल्ली जाऊगा | | | | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | | दिल्ली जाऊगा | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | दिल्ली जाऊगा[CLS]
#      -> Correction applied
#
#  2. CHANGED
#      Original:  वो स्कूल गया हैं
#      Corrected: [CLS] बच्चे हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं[CLS]
#      -> Correction applied
#
#  2. CHANGED
#      Original:  वो स्कूल गया हैं
#      Corrected: [CLS] बच्चे हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं[CLS]
#      -> Correction applied
#
#  3. CHANGED
#      Original:  राम और श्याम खेल रहा है
#      Corrected: [CLS] राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और[CLS]
#      -> Correction applied
#
#  3. CHANGED
#      Original:  राम और श्याम खेल रहा है
#      Corrected: [CLS] राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और[CLS]
#      -> Correction applied
#
#  4. CHANGED
#      Original:  मुझे यह किताब पसंद हैं
#      Corrected: [CLS] मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं[CLS]
#      -> Correction applied
#
#  4. CHANGED
#      Original:  मुझे यह किताब पसंद हैं
#      Corrected: [CLS] मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं[CLS]
#      -> Correction applied
#
#  5. CHANGED
#      Original:  बच्चे पार्क में खेल रहे हैं
#      Corrected: [CLS] बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं[CLS]
#      -> Correction applied
#
#  5. CHANGED
#      Original:  बच्चे पार्क में खेल रहे हैं
#      Corrected: [CLS] बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं[CLS]
#      -> Correction applied
#
#  6. CHANGED
#      Original:  उसके पास बहुत पैसा हैं
#      Corrected: [CLS] उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं हैं हैं[CLS]
#      -> Correction applied
#
#  6. CHANGED
#      Original:  उसके पास बहुत पैसा हैं
#      Corrected: [CLS] उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं हैं हैं हैं उसके पास बहुत पैसा हैं हैं हैं हैं हैं हैं हैं[CLS]
#      -> Correction applied
#
#  7. CHANGED
#      Original:  हम सब मिलकर काम करेगे
#      Corrected: [CLS] हमें सब मिलकर काम करेगेगेगेगेगेगेगे हम सब मिलकर काम करेगेगेगे, हम सब मिलकर काम करेगेगेगे और हम सब मिलकर काम करेगेगेगेगेगेगेगे और हम सब मिलकर काम करेगेगेगेगेगेगेगे और हम सब मिलकर काम करेगेगेगेगे हमारे सब मिलकर काम करेगेगेगेगेगेगेगेगेगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे[CLS]
#      -> Correction applied
#
#  7. CHANGED
#      Original:  हम सब मिलकर काम करेगे
#      Corrected: [CLS] हमें सब मिलकर काम करेगेगेगेगेगेगेगे हम सब मिलकर काम करेगेगेगे, हम सब मिलकर काम करेगेगेगे और हम सब मिलकर काम करेगेगेगेगेगेगेगे और हम सब मिलकर काम करेगेगेगेगेगेगेगे और हम सब मिलकर काम करेगेगेगेगे हमारे सब मिलकर काम करेगेगेगेगेगेगेगेगेगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे होंगे[CLS]
#      -> Correction applied
#
#  8. CHANGED
#      Original:  तुम कहा जा रहे हो
#      Corrected: [CLS] तुम कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको आपको कहा जा रहे हो हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी। तुम कहा जा रहे हो आपको आपको कहा जा रहे हो हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी। तुम कहा जा रहे हो हिन्दी हिन्दी हिन्दी हिन्दी[CLS]
#      -> Correction applied
#
# ==================================================
# Model testing completed!
#
#  8. CHANGED
#      Original:  तुम कहा जा रहे हो
#      Corrected: [CLS] तुम कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको कहा जा रहे हो आपको आपको आपको कहा जा रहे हो हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी। तुम कहा जा रहे हो आपको आपको कहा जा रहे हो हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिंदी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी हिन्दी। तुम कहा जा रहे हो हिन्दी हिन्दी हिन्दी हिन्दी[CLS]
#      -> Correction applied
#
# ==================================================
# Model testing completed!

# %%
# Simple test of the trained model
print(f"Simple Model Test:")
print(f"="*40)

# Test just one sentence
test_sentence = "मैं कल दिल्ली जाऊगा"
print(f"Testing: {test_sentence}")

try:
    corrected = correct_hindi_grammar(test_sentence)
    print(f"Original:  {test_sentence}")
    print(f"Corrected: {corrected}")
    print(f"Changed: {'Yes' if test_sentence != corrected else 'No'}")
except Exception as e:
    print(f"Error: {str(e)}")

print(f"="*40)
# Out:
# Simple Model Test:
# ========================================
# Testing: मैं कल दिल्ली जाऊगा
# Original:  मैं कल दिल्ली जाऊगा
# Corrected: [CLS] मुझे कल दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा कोई कल दिल्ली जाऊगा | | | | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | | दिल्ली जाऊगा | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | दिल्ली जाऊगा[CLS]
# Changed: Yes
# ========================================

# %%
# Test final correction function
print("Testing Final Grammar Correction Function:")
print("=" * 50)

test_sentences = [
    "मैं कल दिल्ली जाऊगा",           # Missing anusvara
    "वो स्कूल गया हैं",              # Verb agreement error
    "राम और श्याम खेल रहा है",         # Plural subject error
    "मुझे यह किताब पसंद हैं",         # Agreement error
    "बच्चे पार्क में खेल रहे हैं"       # Correct sentence
]

for i, sentence in enumerate(test_sentences, 1):
    try:
        corrected = correct_hindi_grammar(sentence)
        changed = sentence != corrected
        
        print(f"\n{i}. {'✓' if changed else '○'} {'CHANGED' if changed else 'UNCHANGED'}")
        print(f"   Original:  {sentence}")
        print(f"   Corrected: {corrected}")
        
    except Exception as e:
        print(f"\n{i}. ✗ ERROR")
        print(f"   Original: {sentence}")
        print(f"   Error: {str(e)[:50]}...")

print(f"\n" + "=" * 50)
# Out:
# Testing Final Grammar Correction Function:
# ==================================================
#
# 1. ✓ CHANGED
#    Original:  मैं कल दिल्ली जाऊगा
#    Corrected: [CLS] मुझे कल दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा कोई कल दिल्ली जाऊगा | | | | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | | दिल्ली जाऊगा | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | दिल्ली जाऊगा[CLS]
#
# 1. ✓ CHANGED
#    Original:  मैं कल दिल्ली जाऊगा
#    Corrected: [CLS] मुझे कल दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा कोई कल दिल्ली जाऊगा दिल्ली जाऊगा मेरा कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा कोई कल दिल्ली जाऊगा | | | | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | | | | दिल्ली जाऊगा | | | | | दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | मैं कल दिल्ली जाऊगा | | | | | | दिल्ली जाऊगा[CLS]
#
# 2. ✓ CHANGED
#    Original:  वो स्कूल गया हैं
#    Corrected: [CLS] बच्चे हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं[CLS]
#
# 2. ✓ CHANGED
#    Original:  वो स्कूल गया हैं
#    Corrected: [CLS] बच्चे हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं भी भी स्कूल गया हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं हैं[CLS]
#
# 3. ✓ CHANGED
#    Original:  राम और श्याम खेल रहा है
#    Corrected: [CLS] राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और[CLS]
#
# 3. ✓ CHANGED
#    Original:  राम और श्याम खेल रहा है
#    Corrected: [CLS] राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और श्याम खेल रहा है राम और[CLS]
#
# 4. ✓ CHANGED
#    Original:  मुझे यह किताब पसंद हैं
#    Corrected: [CLS] मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं[CLS]
#
# 4. ✓ CHANGED
#    Original:  मुझे यह किताब पसंद हैं
#    Corrected: [CLS] मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं मुझे मुझे यह किताब पसंद हैं[CLS]
#
# 5. ✓ CHANGED
#    Original:  बच्चे पार्क में खेल रहे हैं
#    Corrected: [CLS] बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं[CLS]
#
# ==================================================
#
# 5. ✓ CHANGED
#    Original:  बच्चे पार्क में खेल रहे हैं
#    Corrected: [CLS] बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं बच्चे बच्चे पार्क में खेल रहे हैं[CLS]
#
# ==================================================

# %%
# Comprehensive evaluation on dev set
print(f"Comprehensive Evaluation on Dev Set")
print(f"="*60)

# Generate corrections for entire dev set
print(f"Generating corrections for {len(dev_df)} dev samples...")

dev_corrections = []
dev_originals = []
dev_references = []

# Process in batches to avoid memory issues
batch_size = 50
num_batches = (len(dev_df) + batch_size - 1) // batch_size

for batch_idx in tqdm(range(num_batches), desc="Generating corrections"):
    start_idx = batch_idx * batch_size
    end_idx = min(start_idx + batch_size, len(dev_df))
    
    batch_inputs = dev_df['input_text'].iloc[start_idx:end_idx].tolist()
    batch_references = dev_df['output_text'].iloc[start_idx:end_idx].tolist()
    
    # Generate corrections for batch
    for input_text, reference in zip(batch_inputs, batch_references):
        try:
            correction = correct_hindi_grammar(input_text)
            dev_corrections.append(correction)
            dev_originals.append(input_text)
            dev_references.append(reference)
        except Exception as e:
            print(f"Error processing: {input_text[:50]}... - {str(e)[:30]}...")
            dev_corrections.append(input_text)  # Fallback to original
            dev_originals.append(input_text)
            dev_references.append(reference)

print(f"Generated {len(dev_corrections)} corrections")

# Calculate metrics
print(f"\nCalculating evaluation metrics...")

# Exact match accuracy
exact_matches = sum(1 for ref, pred in zip(dev_references, dev_corrections) if ref.strip() == pred.strip())
exact_match_accuracy = exact_matches / len(dev_references) * 100

# Count changes made
changes_made = sum(1 for orig, pred in zip(dev_originals, dev_corrections) if orig.strip() != pred.strip())
change_rate = changes_made / len(dev_originals) * 100

# Count where changes were needed vs made
needs_correction = sum(1 for orig, ref in zip(dev_originals, dev_references) if orig.strip() != ref.strip())
correct_changes = sum(1 for orig, ref, pred in zip(dev_originals, dev_references, dev_corrections) 
                      if orig.strip() != ref.strip() and pred.strip() == ref.strip())

precision = correct_changes / changes_made * 100 if changes_made > 0 else 0
recall = correct_changes / needs_correction * 100 if needs_correction > 0 else 0
f1_score = 2 * precision * recall / (precision + recall) if (precision + recall) > 0 else 0

# Print results
print(f"\nEVALUATION RESULTS:")
print(f"="*40)
print(f"Dataset Statistics:")
print(f"   Total samples: {len(dev_references):,}")
print(f"   Need correction: {needs_correction:,} ({needs_correction/len(dev_references)*100:.1f}%)")
print(f"   Perfect (no change needed): {len(dev_references) - needs_correction:,}")

print(f"\nModel Performance:")
print(f"   Exact match accuracy: {exact_match_accuracy:.1f}% ({exact_matches:,}/{len(dev_references):,})")
print(f"   Changes made: {changes_made:,} ({change_rate:.1f}%)")
print(f"   Correct changes: {correct_changes:,}")

print(f"\nCorrection Metrics:")
print(f"   Precision: {precision:.1f}% (correct changes / total changes)")
print(f"   Recall: {recall:.1f}% (correct changes / needed changes)")
print(f"   F1-Score: {f1_score:.1f}%")

# Show sample results
print(f"\nSample Results:")
print(f"-" * 80)

# Show successful corrections
successful_corrections = [(orig, ref, pred) for orig, ref, pred in zip(dev_originals, dev_references, dev_corrections)
                         if orig != ref and pred == ref]

if successful_corrections:
    print(f"\nSuccessful Corrections (showing first 3):")
    for i, (orig, ref, pred) in enumerate(successful_corrections[:3], 1):
        print(f"   {i}. Original: {orig}")
        print(f"      Reference: {ref}")
        print(f"      Predicted: {pred}")
        print()

# Show failed corrections
failed_corrections = [(orig, ref, pred) for orig, ref, pred in zip(dev_originals, dev_references, dev_corrections)
                     if orig != ref and pred != ref]

if failed_corrections:
    print(f"Failed Corrections (showing first 3):")
    for i, (orig, ref, pred) in enumerate(failed_corrections[:3], 1):
        print(f"   {i}. Original: {orig}")
        print(f"      Reference: {ref}")
        print(f"      Predicted: {pred}")
        print()

print(f"Evaluation completed!")

# Save evaluation results
eval_results = {
    'exact_match_accuracy': exact_match_accuracy,
    'change_rate': change_rate,
    'precision': precision,
    'recall': recall,
    'f1_score': f1_score,
    'total_samples': len(dev_references),
    'needs_correction': needs_correction,
    'changes_made': changes_made,
    'correct_changes': correct_changes
}

with open(f"{CONFIG['output_dir']}/evaluation_results.json", 'w') as f:
    json.dump(eval_results, f, indent=2)

globals()['evaluation_results'] = eval_results
print(f"Evaluation results saved to {CONFIG['output_dir']}/evaluation_results.json")
# Out:
# Comprehensive Evaluation on Dev Set
# ============================================================
# Generating corrections for 527 dev samples...
# Generating corrections:   0%|          | 0/11 [00:00<?, ?it/s]
# Error processing: यह भी पढ़ें  सेहत के लि एजरूरी है रो स्नान करना।... - The following `model_kwargs` a...
# Error processing: शमा को बीजेप् ीने प्रचारकों का शेाड्यूल जारसी का ह... - The following `model_kwargs` a...
# Error processing: नमेरे 'ऐ वतन के गाना लोगों' लता ज ीन ेकेa ेहरू लिए... - The following `model_kwargs` a...
# Error processing: 50 दिनों बाद बिहार में फिर लगे झटके:सीमांचल के जिल... - The following `model_kwargs` a...
# Error processing: तभी जटायु की नजर पड़ी  और वह युद्ध करने लगा रावण स... - The following `model_kwargs` a...
# Error processing: पुिलिस अनंत सिंह तैयार ीइेंडिया के खलाफ लुक सनोटिस... - The following `model_kwargs` a...
# Error processing: जो ाबबइडेन चल रहे हैं... - The following `model_kwargs` a...
# Error processing: विकास भवन में मेडिकल टीम करेगी कार्मिकों का परीक्ष... - The following `model_kwargs` a...
# Error processing: रतन टाटा लिए के इंटरव्यू पलहा भाग पढ़ने लिए दखे-सु... - The following `model_kwargs` a...
# Error processing: मैं जब भी Cristiano Ronaldo के बचपन से लेकर वर्ल्ड... - The following `model_kwargs` a...
# Error processing: Haryana में उद्योगपतियों को उनके उनके उत्पादों की ... - The following `model_kwargs` a...
# Error processing: ये भी हाेग इन सेंटरेों में... - The following `model_kwargs` a...
# Error processing: ब्लाकवार से आकंड़े (एक मार्च से एक दिसबंर ीक स्तिि ... - The following `model_kwargs` a...
# Error processing: सचि वसूचना प्रौद्हयोगिकी दीपक कुमरा ने बताया कि डे... - The following `model_kwargs` a...
# Error processing: हिंदी › न्यूज़ › क्िेकट › I Pफॉफ डु प्लतेसिस ने बता... - The following `model_kwargs` a...
# Error processing: थरूर ने एक प्रश्न के जवाब में कहा कि भारत पाकिस्ता... - The following `model_kwargs` a...
# Error processing: दिल्ली में लगातार घट रहे ICU बेड्स, जानें किस अस्प... - The following `model_kwargs` a...
# Error processing: - स्ट्रीट फोटोग्ाफ ीकरना पसंद -करहते हैं।... - The following `model_kwargs` a...
# Error processing: इस धार्मिक आंदोलन कका मानना है किए मक ऐसा सय होगा,... - The following `model_kwargs` a...
# Error processing: अगर आप शेयर बाजार में पैसा लगाते हो तो ये खबर आपके... - The following `model_kwargs` a...
# Error processing: पाठकगण हैं पीनेवाले, पुस्तक मेरी मधुशाला... - The following `model_kwargs` a...
# Error processing: पुजारी पं.शंकर गुरु ने बताया तड़के 4 बजे मंदिर के प... - The following `model_kwargs` a...
# Error processing: लमैच के दौरान विराट के खिलाफ ैLB की सफल अपील करते ... - The following `model_kwargs` a...
# Error processing: अगले ेज प,र अक्टूबर के इवेंटल...... - The following `model_kwargs` a...
# Error processing: महाराष्ट्र में नौकरी बहुत है लेकिन मजदूर कम हैं : ... - The following `model_kwargs` a...
# Error processing: पत्र में आगे कहा गया है कि संसदीय बोर्ड यह निर्णय ... - The following `model_kwargs` a...
# Error processing: और कहने लगे... - The following `model_kwargs` a...
# Error processing: वीकेंड परर पार कमाई 50 रको़ पार... - The following `model_kwargs` a...
# Error processing: है। मतदान समाप्ति की समाप्ति के दौरान भी लोग अनेक ... - The following `model_kwargs` a...
# Error processing: -गणित में यह बात अहम है कि यह अभ्यास का विषय है। य... - The following `model_kwargs` a...
# Error processing: यात्रियों की सुविधा के लिए होगा 9000 करोड़ का निवे... - The following `model_kwargs` a...
# Error processing: मानसा। शहर दूसरे में चल रही टीमों 59वीं स्तरीय अंड... - The following `model_kwargs` a...
# Error processing: किसी को कष्ट कष्ट देने के लिए पत्थर या ढेले का प्र... - The following `model_kwargs` a...
# Error processing: संडे का फन हुआ छू... - The following `model_kwargs` a...
# Error processing: 12 हजार प्रवासियों की मदद कर चुके हैं सोनू सूद, बो... - The following `model_kwargs` a...
# Error processing: जान! समंंदर में मछली ापकड़ रनहा थमा मछुआरा, अचानक ... - The following `model_kwargs` a...
# Error processing: 6  अक्टूबर को दिए गए अपने आदेश में एनबीएसए ने कहा,... - The following `model_kwargs` a...
# Error processing: अधिांश मेाहल्लों को नदी काप ान ीसीब नहीं... - The following `model_kwargs` a...
# Error processing: अरग संकट ेमं फंसे हैं आपके तो है े बात... - The following `model_kwargs` a...
# Error processing: इसके अलावा सारा बहुत जल्द फिल्म अतरंगी रे में नजर ... - The following `model_kwargs` a...
# Error processing: एतहासिक,ा पैराणिक एवं धा्र्मिक स्थलों की जीवंतप ्र... - The following `model_kwargs` a...
# Error processing: चीन पुरुष में ‘लेट्स रेसल, डैड’ नाम के से रिलीज हु... - The following `model_kwargs` a...
# Error processing: iOS 14.5 बीटा अपडेट में ड्यूल-सिम 5G सपोर्ट भी उपल... - The following `model_kwargs` a...
# Error processing: पाक ओपनर रिजवान ने टी20 में रचा इतिहास, एक कैलेंडर... - The following `model_kwargs` a...
# Error processing: ट्रेडिंग प्लेटफार्म सक्षम बनाया गया है की उसके स्व... - The following `model_kwargs` a...
# Error processing: महाराष्ट्र में नौकरी बहुत है लेकिन मजदूर कम हैं : ... - The following `model_kwargs` a...
# Error processing: पत्र में आगे कहा गया है कि संसदीय बोर्ड यह निर्णय ... - The following `model_kwargs` a...
# Error processing: और कहने लगे... - The following `model_kwargs` a...
# Error processing: वीकेंड परर पार कमाई 50 रको़ पार... - The following `model_kwargs` a...
# Error processing: है। मतदान समाप्ति की समाप्ति के दौरान भी लोग अनेक ... - The following `model_kwargs` a...
# Error processing: -गणित में यह बात अहम है कि यह अभ्यास का विषय है। य... - The following `model_kwargs` a...
# Error processing: यात्रियों की सुविधा के लिए होगा 9000 करोड़ का निवे... - The following `model_kwargs` a...
# Error processing: मानसा। शहर दूसरे में चल रही टीमों 59वीं स्तरीय अंड... - The following `model_kwargs` a...
# Error processing: किसी को कष्ट कष्ट देने के लिए पत्थर या ढेले का प्र... - The following `model_kwargs` a...
# Error processing: संडे का फन हुआ छू... - The following `model_kwargs` a...
# Error processing: 12 हजार प्रवासियों की मदद कर चुके हैं सोनू सूद, बो... - The following `model_kwargs` a...
# Error processing: जान! समंंदर में मछली ापकड़ रनहा थमा मछुआरा, अचानक ... - The following `model_kwargs` a...
# Error processing: 6  अक्टूबर को दिए गए अपने आदेश में एनबीएसए ने कहा,... - The following `model_kwargs` a...
# Error processing: अधिांश मेाहल्लों को नदी काप ान ीसीब नहीं... - The following `model_kwargs` a...
# Error processing: अरग संकट ेमं फंसे हैं आपके तो है े बात... - The following `model_kwargs` a...
# Error processing: इसके अलावा सारा बहुत जल्द फिल्म अतरंगी रे में नजर ... - The following `model_kwargs` a...
# Error processing: एतहासिक,ा पैराणिक एवं धा्र्मिक स्थलों की जीवंतप ्र... - The following `model_kwargs` a...
# Error processing: चीन पुरुष में ‘लेट्स रेसल, डैड’ नाम के से रिलीज हु... - The following `model_kwargs` a...
# Error processing: iOS 14.5 बीटा अपडेट में ड्यूल-सिम 5G सपोर्ट भी उपल... - The following `model_kwargs` a...
# Error processing: पाक ओपनर रिजवान ने टी20 में रचा इतिहास, एक कैलेंडर... - The following `model_kwargs` a...
# Error processing: ट्रेडिंग प्लेटफार्म सक्षम बनाया गया है की उसके स्व... - The following `model_kwargs` a...
# Generating corrections:   9%|▉         | 1/11 [00:00<00:02,  3.72it/s]
# Error processing: बकौल मोद, ्“कोवि-ड19 के संकट बीच बड़ा इतने समय लंब... - The following `model_kwargs` a...
# Error processing: केरल में एक चुनावी रैली के दौरान भाजपा के वरिष्ठ न... - The following `model_kwargs` a...
# Error processing: खिलाड़ियों के तैयार किया जाएगा पैकेज... - The following `model_kwargs` a...
# Error processing: मनली मसएतडीएम रमन घरसंगी ने कहा क कुल्लवी नृत्य मे... - The following `model_kwargs` a...
# Error processing: क़तर की राजधानी दोहा में यमन में मानवाधिकार की स्थ... - The following `model_kwargs` a...
# Error processing: चश्मदीद मजदूरों की माने तो दिल्ली के बिलकुल बॉर्डर... - The following `model_kwargs` a...
# Error processing: वीवीएस लक्ष्मण और राहुल द्रविड़ अपनी ऐतिहासिक साझे... - The following `model_kwargs` a...
# Error processing: निम्न सारणी में चेरापुंजी और मौसिनराम में १९७० से ... - The following `model_kwargs` a...
# Error processing: सीएम वीरभद्र सिंह ने बताया के कि फोटो) राजधानी को ... - The following `model_kwargs` a...
# Error processing: दिल्ली सरकार ने वन नेशन वन राशन कार्ड योजना लागू क... - The following `model_kwargs` a...
# Error processing: हाईवे हो सकता ह ाधित... - The following `model_kwargs` a...
# Error processing: सबसे दास्ती कर पा रहे हैं हमारि मनोरंजन हो पा रहि ... - The following `model_kwargs` a...
# Error processing: ये 6 भी पढ़ें- में बीजेपी की हत्या आरोप के में CPM... - The following `model_kwargs` a...
# Error processing: अपने दादा धर्मेंद्र और पिता से कम नहीं सनी देओल का... - The following `model_kwargs` a...
# Error processing: यह डिवाइस हमारे सामने भी प्रस्तुत की गई थी। यह सिर... - The following `model_kwargs` a...
# Error processing: मंडला माइनिंग को बनाया आधार... - The following `model_kwargs` a...
# Error processing: दहेज के लिए पैर की चार अंगुलियां काटीं, फिर रेलवे ... - The following `model_kwargs` a...
# Error processing: इससे पहले भी अफवाह फैली थी कि रामचरितमानस के बालका... - The following `model_kwargs` a...
# Error processing: राममंदिर पर विपक्ष स्पष्ट करे अपना इरादा: अमित शाह... - The following `model_kwargs` a...
# Error processing: ICC Wतorl1d Cup 20 12011म ें हारय्दमिक ने पूरी रा ... - The following `model_kwargs` a...
# Error processing: चेतन हंसराज ने बतौर चाइल्ड आर्टिस्ट साल 1980 से अप... - The following `model_kwargs` a...
# Error processing: स्वच्छता सर्वेक्षण विषय पर निबंध प्रतियोगिता में श... - The following `model_kwargs` a...
# Error processing: बिलासपुर में उपचुना वके िए कि गए पर्चे दाखिलल... - The following `model_kwargs` a...
# Error processing: धोनी से सौरभ कुमार कनेक्शन का... - The following `model_kwargs` a...
# Error processing: - ्रैफटिक क्ंट्रोलर, काउंटडाउन टसाइम,र आधुनिक ट्रै... - The following `model_kwargs` a...
# Error processing: बहुत ज्यादा मल-जल के कारण ये देखा गया है कि यह पान... - The following `model_kwargs` a...
# Error processing: मुरली ने विजय जड़ा सिडनी में जड़ा शतक, शानदार टीम ... - The following `model_kwargs` a...
# Error processing: मध्य प्रदेश: शराब पर अतिरिक्त टैक्स लगाकर गोशाला च... - The following `model_kwargs` a...
# Error processing: हिंदमाता, परेल पर ओबी मांगो... - The following `model_kwargs` a...
# Error processing: अंधविश्वास के चलते अराजकतत्वों ने मासूम के साथ कर ... - The following `model_kwargs` a...
# Error processing: एक बहु-एजेंसी निकाय द्वारा लिए समूह और ख ग (गैर-तक... - The following `model_kwargs` a...
# Error processing: जिले में नहीं मिला कोई भी संक्रमित, सक्रिय चार होम... - The following `model_kwargs` a...
# Error processing: अर्दोग़ान ने कहाः "अगर बाग़ी हफ़्तर ने अपने देश के... - The following `model_kwargs` a...
# Error processing: अयोध्या के शिवकुारम  महीने हले मुबई ेथ। इेल्टरयिशि... - The following `model_kwargs` a...
# Error processing: लोगे ने समय के साथ यह समझा है कि किस प्रकार शिक्षा... - The following `model_kwargs` a...
# Error processing: ‘‘अधूरे-अधूरे लेकर सपन रंग न लौटे/ पूरे हुए वचन के... - The following `model_kwargs` a...
# Error processing: लुधयियाना सड़क में धंसी... - The following `model_kwargs` a...
# Error processing: रज्य के उस्मानाबाकद राज्य ज़िले में मेंए क प्रदर्श... - The following `model_kwargs` a...
# Error processing: ईद को ेकर नए कपड़ों ा वितरण... - The following `model_kwargs` a...
# Error processing: - आरोपी शिक्षिका, उनके पति व बेटे तथा बेटी हैं जमा... - The following `model_kwargs` a...
# Error processing: साल का पहला ग्रहण अमरिेका के भाग, यूरोण, एशिया कमे... - The following `model_kwargs` a...
# Error processing: कुछ देर बाद सूरज ढला अंधेरा हुआ।... - The following `model_kwargs` a...
# Error processing: सब कुछ ठीक है बस पीछे ये कौन है... - The following `model_kwargs` a...
# Error processing: जी हां..टेलिवीज़न पर आप सभी एक्ट्रेसेस को मेकअप दे... - The following `model_kwargs` a...
# Error processing: मुखबरी के शक में सास-बहू से की मारपीट... - The following `model_kwargs` a...
# Error processing: प्ररेस टीव की रिपर्ट के अनुार प्रांत राजधाकनीग हरा... - The following `model_kwargs` a...
# Error processing: वनडे में रोहित ने 232 छक्के मारे हैं. टेस्ट में रो... - The following `model_kwargs` a...
# Error processing: उन्होंने कहा, "सभी राज्यों को समान महत्व दिया जाना... - The following `model_kwargs` a...
# Error processing: वह दिल्ली के स्कूल ऑफ ओपन लर्नंिगस े स्नतक रही कर ... - The following `model_kwargs` a...
# Error processing: को ट्रेन किया ने रोक यात्रियों ने किया एक घन्टा तक... - The following `model_kwargs` a...
# Error processing: मदी की की टिप्पदणी टिप्पणी पर ट्विटर पर भड़केो लग... - The following `model_kwargs` a...
# Error processing: 4. आपके पास केवल अपने दिन पूरे बारे में के लिए केव... - The following `model_kwargs` a...
# Error processing: मुंबई. अभदिनेत्री शिल्पा ंेट्टी कुंद्रा इन दिनों म... - The following `model_kwargs` a...
# Error processing: अनुकंपा शिक्षक संघ के  प्रदेश अध्यक्ष की मौत के बा... - The following `model_kwargs` a...
# Error processing: संवाद सहयोगी निरसा चार-पांच दिनों से हो रही बारिश ... - The following `model_kwargs` a...
# Error processing: सल्खू टेघरा ेगूसराय, बेगूसारय, बिहार स्थित एकै ाँव... - The following `model_kwargs` a...
# Error processing: धमाल देखकर मजा आ गया। पूरी फिल्म में हँसी के फव्वा... - The following `model_kwargs` a...
# Error processing: फिल्म "संभव से परे" अद्वितीय कहा जाता है। गर्भावस्... - The following `model_kwargs` a...
# Error processing: नियम अनुसार ये जल एक स्थान पे साफ होना चाहिए, फिर ... - The following `model_kwargs` a...
# Error processing: शर्मा ने बेटे का नाम किया खुलासा, नीति सिंगर मोहन ... - The following `model_kwargs` a...
# Error processing: रिश्तेदार रिश्तेदार के से पुत्र से की जा रही पूछता... - The following `model_kwargs` a...
# Error processing: घर-घर जाकर मतदाताओं को जागरूक करें जन शिक्षकः कलेक... - The following `model_kwargs` a...
# Error processing: 50 की उम्र के बाद ऐसा होना चाहिए आहार, इन मिथकों स... - The following `model_kwargs` a...
# Error processing: अब घायल सड़क पर नहीं पड़े रहेंगे ऑटो एंबुलेंस देगी... - The following `model_kwargs` a...
# Error processing: 16 अपनी और कुटुम्ब की सेवा के साथ समाज की सेवा करन... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ शाहजहांपुर प्रदेश उत्तर शाहजहांपुर टीड... - The following `model_kwargs` a...
# Error processing: के भापा हाथ में उत्तर पथ्रदेश... - The following `model_kwargs` a...
# Error processing: हिंंदी न्नयूज़ बिहार कशनगंज: शहरी कषेत्र में आवश्यक... - The following `model_kwargs` a...
# Error processing: 'द ज़ोया फैक्टर' में अंगद बेदी के लुक के पीछे करण ... - The following `model_kwargs` a...
# Error processing: सरकारी संपत्ति को नुकसान पहुंचाने पर भड़की महिलाएं... - The following `model_kwargs` a...
# Error processing: बॉलीुड चुस्कड : आलिया और घर अपने ेमं बानएंगे ऋषि ख... - The following `model_kwargs` a...
# Error processing: शीर्षा ांच न्डयूयॉर्क नका में मिडटउा मैनहट्टन ुऔर ... - The following `model_kwargs` a...
# Error processing: समाचार एजेंसी 'डीपीए' के के अनुसार, उप गृह मंत्री ... - The following `model_kwargs` a...
# Error processing: कोई मुंह खोलने को तैयार नहीं... - The following `model_kwargs` a...
# Error processing: अंग्ेजी में इनें से कौन सा शब्द हिंदीभ ाष से आाय ह... - The following `model_kwargs` a...
# Error processing: सोशलमिडिया के दो रुप- (एक) साकारत्मक (दो) नाकारत्म... - The following `model_kwargs` a...
# Error processing: प्रेरक कि हरियाा क ेसंयोजक करण संिह ने कहा शिक्षा ... - The following `model_kwargs` a...
# Error processing: कम दे रहा था अनाज, दुकान में एक से अधिक दरवाजे पाए... - The following `model_kwargs` a...
# Error processing: थकान औवर मानसिक तानव में लभादायक... - The following `model_kwargs` a...
# Error processing: एपल आईफोन ने 6 आईफोन प्लस का पेटेंट मुकदमा जीता... - The following `model_kwargs` a...
# Error processing: लेकिन वह अपने बेटे को भेजने के लिए तैयार हो गईं.... - The following `model_kwargs` a...
# Error processing: गर्मियों की बात है और कुछ दस- बारह वर्ष की आयु थी।... - The following `model_kwargs` a...
# Error processing: अंतिम चेतावनी बनी मौत की वजह... - The following `model_kwargs` a...
# Error processing: तमाम अदालतों और सीबीआई मुख्ययालय के बी कई दिन चली ... - The following `model_kwargs` a...
# Error processing: कोरोना से रहेगा मरने वाले नागरिकों को देगा श्रद्धा... - The following `model_kwargs` a...
# Error processing: - सूरत से बाघेर घाटी तक के रास्ते में सुराग जुटा र... - The following `model_kwargs` a...
# Error processing: जब से मोबाइल फोन एवं इंटरनेट की सुविधा सोलभ हुई है... - The following `model_kwargs` a...
# Error processing: रामलीला कमेटी का हुआ चुनाव... - The following `model_kwargs` a...
# Error processing: न्यूयॉर्क के रहने वाले टेलर पियर्सन ऐसे ही शख़्स ह... - The following `model_kwargs` a...
# Error processing: यही कारन है कि फुट डालों और शासन करों की निति एक ब... - The following `model_kwargs` a...
# Error processing: अब पुलिस के सिर सपा नेता ने मढ़ दिए आरोप... - The following `model_kwargs` a...
# Error processing: श्रीि शर्मा हने हा कि इसके अलावा शहर में जहां कहीं... - The following `model_kwargs` a...
# Error processing: त्रिपाठी के बाद सूर्यप्रताप शाही को बागडोर सौंपी ग... - The following `model_kwargs` a...
# Error processing: खुशखबरी: होली से ठीक पहल ेमैोदी सरकार ने दिया तोहफ... - The following `model_kwargs` a...
# Error processing: एक और चीज जो हम रामायण से सीख सकते हैं कि जब समारे... - The following `model_kwargs` a...
# Error processing: दुबई। भारत रोमांच की पराकाष्ठा तक पहुंचे फाइनल में... - The following `model_kwargs` a...
# Error processing: उन्ह‍ोंनेह ाथ जोड़कर सभी से ीमास्‍क पहनने की की अी... - The following `model_kwargs` a...
# Generating corrections:  27%|██▋       | 3/11 [00:00<00:01,  7.89it/s]
# Error processing: पांचवें मुकदमे उन्हें आज़ादी में के बाद एक कराची म... - The following `model_kwargs` a...
# Error processing: चाणक्य के प्रतिशोध से लेकर... - The following `model_kwargs` a...
# Error processing: सोशल मीडिया अभी के समाज की बहुत बड़ी मुसिबत है।... - The following `model_kwargs` a...
# Error processing: अंाह।स चंबल के लाड़ल ेसपूतल शहीद हवलदार रामगोविंद ि... - The following `model_kwargs` a...
# Error processing: मैं जीवन में अनेक भविष्य के करियर चुन सकता था, परं... - The following `model_kwargs` a...
# Error processing: मध्य प्रदेश के मंत्री पीस शर्समा: बागी विधायकों को... - The following `model_kwargs` a...
# Error processing: हालांकि उस समय में पीलिया से क्षतिग्रस्त था।... - The following `model_kwargs` a...
# Error processing: ना किसी है ेस अपेक्षा....क... - The following `model_kwargs` a...
# Error processing: 4 सितंबर: इन घटनाओं को याद भी कर आज खड़े हैं जाते ... - The following `model_kwargs` a...
# Error processing: 6 से 7 काली मिर्च के दाने... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ › पश्चिम बंगाल › नड्डा हमले के बाद मुख... - The following `model_kwargs` a...
# Error processing: भाजपा नेताओं ने अमित शाह के स्वास्थ्य के बारे में ... - The following `model_kwargs` a...
# Error processing: इस प्रदुषण के कारण, इस पर्यावरण रहने वाले, जिव-जन्... - The following `model_kwargs` a...
# Error processing: बेंगलुरू में सोमवार (20 फरवरी) को पांच अप्रेल से श... - The following `model_kwargs` a...
# Error processing: पानी की है समस्यु तो घुमाइए ोन... - The following `model_kwargs` a...
# Error processing: शहाईवे पर स्पेशल ाअलर्ट... - The following `model_kwargs` a...
# Error processing: लॉकडााऊन अंदर नड़ेस ढली मिलते ही कोरोना ने पकड़ी फिर... - The following `model_kwargs` a...
# Error processing: म्ध्य प्रदेश में प्रदेश कांग्रेस पऔ्र खकमलनाथ और प... - The following `model_kwargs` a...
# Error processing: बच्चों पढ़ाई की नी मुसीबत बढ़़ सराकर के ी पास नहीं... - The following `model_kwargs` a...
# Error processing: नईदुनिया ालास सेहत से,व िशेषज््ञ योग व ध्यान का ्प... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ उत्तराखंड बागेश्वर काफलीगैर में तहसीलद... - The following `model_kwargs` a...
# Error processing: PSC लews: एक महीने में जारी किय पीएससी ्ने ्रारंभि... - The following `model_kwargs` a...
# Error processing: पाकिसतानी वीना अभिने्री वमलिक दिनेों अपनी हआमने वा... - The following `model_kwargs` a...
# Error processing: कश्मीर पर टिप्पणी... - The following `model_kwargs` a...
# Error processing: हमीरपुर में 22 कांग्रेस नेता लिए हिरासत में... - The following `model_kwargs` a...
# Error processing: सिर्फ नेता ही नहीं बॉलिवुड एक्टर सोनू सूद भी परीक्... - The following `model_kwargs` a...
# Error processing: ये रिफाइन तेल बनता कैसे हैं? किसी भी तेल को रिफाइन... - The following `model_kwargs` a...
# Error processing: इसलिए अत्यंत फलदायी है इस बार की नवरात्रि... - The following `model_kwargs` a...
# Error processing: इस रात दिवाली कैसे (मो.रफी,शमशाद बेगम और आशा भोंसल... - The following `model_kwargs` a...
# Error processing: बिजली बचाने में लखनवाइट्स बेजोड़... - The following `model_kwargs` a...
# Error processing: RBI की जांच रिपोर्ट में गड़बड़ी होने के बाद भी कंप... - The following `model_kwargs` a...
# Error processing: GSLV मार्क 3D2 रॉकेट ने जीसैट-29 को सफलतापूर्वक अं... - The following `model_kwargs` a...
# Error processing: रक्षा मंत्री रात 8.40 बजे की फ्लाइट से दिल्ली लौटी... - The following `model_kwargs` a...
# Error processing: मढ़ैया में जा में रहे एबीवीपी आखिर कार्यकर्ता, क्य... - The following `model_kwargs` a...
# Error processing: उदाहरण स्वरूप रावण एक उच्च योणी का ब्राह्मण था जो ... - The following `model_kwargs` a...
# Generating corrections:  45%|████▌     | 5/11 [00:00<00:00, 10.20it/s]
# Error processing: वजली-अस०३, पौडी तहसील में भारत के उत्तराखण्ड राज्य... - The following `model_kwargs` a...
# Error processing: बरेली के सेल्समैनों से 30 हजार रुपये की लूट... - The following `model_kwargs` a...
# Error processing: लखीपमुर हंसा को लेकर किसानों का 'रेलर ोको आंदोन' आ... - The following `model_kwargs` a...
# Error processing: सेलिना जेटली को मिलेंगे 60 लाख रुपए... - The following `model_kwargs` a...
# Error processing: UPJE E2020 े लिअये आवेदन करने कीब अंतिम तिथि एनक ब... - The following `model_kwargs` a...
# Error processing: अपने रहे दावे... - The following `model_kwargs` a...
# Error processing: बाइडन ने कहा कि अमेरिका वायरस के खिलाफ जंग में अब ... - The following `model_kwargs` a...
# Error processing: किसान नेता राकेश टिकैत ने भी से पहले कहा हमें ट्रै... - The following `model_kwargs` a...
# Error processing: ब्याज दरें घटने की आस में सेंसेक्स 350 अंक उछला... - The following `model_kwargs` a...
# Error processing: इस कॉलेज फिजिक्स, में ताइवान साइन के में प्रोफेसर ... - The following `model_kwargs` a...
# Error processing: स्ट्रेस लेवल रहता है कंट्रोल... - The following `model_kwargs` a...
# Error processing: ताइवान में नौक-ाजहा, में टक्कर, 4 मरे... - The following `model_kwargs` a...
# Error processing: वनां होम पएेज पर सीनियर ऑफिसर के लिए िए गए नोटिफिक... - The following `model_kwargs` a...
# Error processing: 6 'जमरने' से पहले - खुल के 'कजीा'... - The following `model_kwargs` a...
# Error processing: 38 साल की उम् रमैदान उसमर वापसी कदरेंगे अब्दुल र्ज... - The following `model_kwargs` a...
# Error processing: अगर मुख्य मूर्तिकार स्टीफन मैनफील्ड की मानें तो शा... - The following `model_kwargs` a...
# Error processing: चो' में 'चरणदास दनहीं में लकिन नय कलेवर -मबाइल पर ... - The following `model_kwargs` a...
# Error processing: उत्तर प्रदेश के  मुख्यमंत्री योगी आदित्यनाथ ने शनि... - The following `model_kwargs` a...
# Error processing: अमृत महोत्सव के तहत दयानंद आयुर्वेदिक कालेज का स्ट... - The following `model_kwargs` a...
# Error processing: परिसर में २३९ एकड़ में कुक्करहल्ली में झील २३९... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ उत्तराखंड उत्तरकाशी दर्शन लाल बने पीटी... - The following `model_kwargs` a...
# Error processing: सहारनपुर में 54.18... - The following `model_kwargs` a...
# Error processing: जब यह बात अयोध्या पहुं‌ची की चारो पुत्र वापस आ रहे... - The following `model_kwargs` a...
# Error processing: -उपाध्यक्ष और महामंत्री पर निर्दलीय ने की जीत दर्ज... - The following `model_kwargs` a...
# Error processing: 2. जिस जगह पर केमिकल अटैक हुआ हो वहां से तुरंत दूर... - The following `model_kwargs` a...
# Error processing: जसपुर में डॉक्टर के लिए सरकार का पुतला फूंकेगी समि... - The following `model_kwargs` a...
# Error processing: -शिवपुर रेलवे स्टेशन पर खुला रिजर्वेशन टिकट काउंटर... - The following `model_kwargs` a...
# Error processing: चिटौद में चण का चौथा र णपूर्ण... - The following `model_kwargs` a...
# Error processing: कॉनवेल्थ में विजेताओं के गले में डाला जाने वालां स... - The following `model_kwargs` a...
# Error processing: मुख पृष्ठ > आजकी वार्ता > अशिया > भारत > नर्इ देहल... - The following `model_kwargs` a...
# Error processing: केोरोना संक्मण सेे बचाव मेंआ पके लिए सबसे अहमह ै म... - The following `model_kwargs` a...
# Error processing: आरटीओ में रोजाना लर्निग ासइेंस- 15-010... - The following `model_kwargs` a...
# Error processing: आज का भारत 1965 वाला भारत नहीं रह गया है। आज देश क... - The following `model_kwargs` a...
# Error processing: वहीं नोट के दाईं ओर 500 रुपए लिखा है, दिखता लिखा न... - The following `model_kwargs` a...
# Error processing: राजधानी पटना में कोरोना मरीजों की संख्या 7 हुई... - The following `model_kwargs` a...
# Error processing: आ आरोपी को केंे न्यायालय में पेश... - The following `model_kwargs` a...
# Error processing: श्याम प्रभु खाटू वालोूं की महिमा काख िया गुणगन... - The following `model_kwargs` a...
# Error processing: जालसाजों ने डेयरी खोलने के नाम पर ठगे डेढ़ लाख रुप... - The following `model_kwargs` a...
# Error processing: खासकर जब आपकी आयु 60 वर्ष या उससे अधिक उम्र की हैं... - The following `model_kwargs` a...
# Error processing: हम अमरीका से नहीं डरते, क्षेत्र और ईरान से अमरीका ... - The following `model_kwargs` a...
# Error processing: इस लॉनमॉवर के बारे में एक और सकारात्मक बात यह है क... - The following `model_kwargs` a...
# Error processing: ग़ौरतलब है कि इस्राईल बअपने परमाु हथियारों क प्ोरग... - The following `model_kwargs` a...
# Error processing: इस आरोप के वजाब ैको मैकुलम ने किया सिरे सेस खारज... - The following `model_kwargs` a...
# Error processing: बता दें ाक दीपिका े ससुरालवाले ुमस्िलम है बावजू इस... - The following `model_kwargs` a...
# Error processing: नोह पोलिंग बथ पर मतदाताओं की लंबी-लंबीक ताेरं... - The following `model_kwargs` a...
# Error processing: महोबमा : वैक्सीन की कलमी से सेंटरो,ं का कामम ठ, हर... - The following `model_kwargs` a...
# Error processing: शोभा डे ने संवादाताओं को बताया कि उन्होंने ट्विटर ... - The following `model_kwargs` a...
# Error processing: दो दिनों बाद बिहार में कोरोना नये मामलों आंकड़ा दो... - The following `model_kwargs` a...
# Error processing: उन्होंने कि डोरंडा बताया में रह पहले कर उस दुकान र... - The following `model_kwargs` a...
# Error processing: तेल, मात्रा या विटुमेन या भूरे कोयले के आसवन से एक... - The following `model_kwargs` a...
# Error processing: भारत का पहला स्वदेशी टीका... - The following `model_kwargs` a...
# Error processing: इंदौर पहुंचे केजरीवाल ने शिवराज को ने दिया ये ऑफर... - The following `model_kwargs` a...
# Error processing: कलेक्टर डॉ. मसूद अख्तर ने बताया कि जिले के किसानों... - The following `model_kwargs` a...
# Error processing: जिल ापचायत सदस्यंो का नामांकन बौराड़ी में होगचा... - The following `model_kwargs` a...
# Error processing: कुछ लोग सोशल मीडिया से पैसा कमा रहे हैं तो बाकियों... - The following `model_kwargs` a...
# Error processing: इंफेक्शन बच्चेानीव मं इंफे्नश हो से हो रहा था रक्त... - The following `model_kwargs` a...
# Error processing: गिलानी पर लग चुके हैं ये आरोप... - The following `model_kwargs` a...
# Error processing: इग्‍नू हिंदी में ऑनलाइन एमए कार्यक्रम शुरु इग्‍नू... - The following `model_kwargs` a...
# Error processing: इस अभियान के तहत 2022 को प्रक्षेपित करने है, की यो... - The following `model_kwargs` a...
# Error processing: अंचल अधिकारी (सीओ) इंदु सिद्धार्थ ने कहा कि प्रथम ... - The following `model_kwargs` a...
# Error processing: जवाहरलाल नेहरू के पास चीन को लेकर कोई बड़ा अनुभव नह... - The following `model_kwargs` a...
# Error processing: वास्तुशास्त्र के अनुसार आपके दरवाजे के बाहर चप्पल ... - The following `model_kwargs` a...
# Error processing: इन आतंकियों के मोबाइल में ऐसे ऐप डाउनलोड थे, जो प्... - The following `model_kwargs` a...
# Error processing: मल्लिकार्जुन खड़गे ने कहा-बजट कल पेश करना कहा-बजट... - The following `model_kwargs` a...
# Error processing: किश्‍वर-प्रिंस के बीच हो सकती है तकरार ?... - The following `model_kwargs` a...
# Error processing: नौकरानी ने देखा... - The following `model_kwargs` a...
# Error processing: पार्षद की तक सुन रहे अधिकारी!... - The following `model_kwargs` a...
# Error processing: आर्यभट्ट , भास्कराचार्य ,तेनाली रामाकृष्ण ,कालिदास... - The following `model_kwargs` a...
# Error processing: ख़रतूम में विदेश मंत्रालय की इमारत के सामने बड़ी स... - The following `model_kwargs` a...
# Error processing: बॉलावुड अभिनेत्री आलिया भट्ट, शहनाज गिल,  एयरपोर्ट... - The following `model_kwargs` a...
# Error processing: चयन प्रक्रिया: इंटरव्यू और परीक्षा के आधार पर चयन ... - The following `model_kwargs` a...
# Error processing: आगर-मालवा से नहीं, इंदौर-भोपाल और ग्वालियर से मुख्... - The following `model_kwargs` a...
# Error processing: 44 दिन में एक पूरा परिवार खत्म हो गया ये पूरी घटना... - The following `model_kwargs` a...
# Error processing: पूजन के मुहूरत- पूर्णिमा तिथि सोमाव, 20 तिबर 2021 ... - The following `model_kwargs` a...
# Error processing: अब आपको सबसे ऊपर एक लिंक फॉर्मर्स कार्नर दिखाई देग... - The following `model_kwargs` a...
# Error processing: -ीनति आयगक ेी मुख्य कार्यकारी अधिकारी अमिताभ कांतभ... - The following `model_kwargs` a...
# Error processing: स्वास्थ्य और समृद्धि के लिए पंचामृत दूध, दही, बूरा... - The following `model_kwargs` a...
# Error processing: निजी अस्पतालों में चिकित्सा के करीब करीब सभी संवर्... - The following `model_kwargs` a...
# Error processing: * गृह मंत्रालय अमेरिका से तकनीकी मदद की मांग करने ... - The following `model_kwargs` a...
# Error processing: रूस के ऊर्जामंत्री ने घोषणा की थी कि दोनों देश दक्... - The following `model_kwargs` a...
# Error processing: ेमं सा्कूल सुबह नहीं शम को काया जाता है राष्ट्रगान... - The following `model_kwargs` a...
# Error processing: महिंदा राजपक्षे और उनके भाई राजपक्षे गोटाभाया क़री... - The following `model_kwargs` a...
# Error processing: यह वह सीरियल था, जिसने मुझे टीवी पर एक अलग मुकाम द... - The following `model_kwargs` a...
# Error processing: पीड़िता बया नका... - The following `model_kwargs` a...
# Error processing: खासतौर पर पीठ पर और रीढ़ की हड्डी के पास मालिश करते... - The following `model_kwargs` a...
# Error processing: गुप्त नरवाात्रि वयिशेषन सिद्धियों को प्राप्त करने ... - The following `model_kwargs` a...
# Error processing: विधान के लिए मनोनयन पर फंसा तो उद्धव पेच ने किया म... - The following `model_kwargs` a...
# Error processing: गठ्स हिो्दोस्तां: ऑफ किसी ने बताया बोरिंग, तो ोोरि... - The following `model_kwargs` a...
# Error processing: जयपुर। जयपुर के प्रताप नगर इलाके में रविवार तड़के ... - The following `model_kwargs` a...
# Error processing: स्थान: महरुआ बाजार का गुगुरगंज चौक... - The following `model_kwargs` a...
# Error processing: ऐसे में आस-पास वाले शहर जो नदी के किनारे पर स्थित ... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ ज़बिहार साासराम िद्यार्थी परिषद काह ुआ ... - The following `model_kwargs` a...
# Error processing: साहित्यिक कार्य.... - The following `model_kwargs` a...
# Error processing: गुरु नानक जयंती कैसे मनाई जाती है... - The following `model_kwargs` a...
# Error processing: महर्षि दयानंद सरस्वती विश्वविद्यालय के तत्वावधान म... - The following `model_kwargs` a...
# Error processing: 70 एक किलोमीटर बार चार्ज करने चार्ज पर चलती है... - The following `model_kwargs` a...
# Error processing: पीजीआई में एक बडा बदलाव पढ़े पढ़े होने जा रहा है, एक... - The following `model_kwargs` a...
# Error processing: अब आपके शरर ीमेंर प्‍लेसेंट ाबन ाचुका हैर जो अम्‍ल... - The following `model_kwargs` a...
# Error processing: पूछताछ के दौरान मुंबई पुलिस ने वाजिद के परिवारवालो... - The following `model_kwargs` a...
# Error processing: 5 अक्तूबर इन गांव चूक गए िसान गए नई अना नाूरनौल मं... - The following `model_kwargs` a...
# Error processing: 3. दलजीत सिंह... - The following `model_kwargs` a...
# Error processing: 65. सर्वांगघात  यह जन्मजात मस््ति्षक का रोमग है।... - The following `model_kwargs` a...
# Error processing: दो दिनों की के तलाश के शहजाद बाद अधिकारियों ने पकड... - The following `model_kwargs` a...
# Error processing: पिछले वर्ष की तुलना ुनतलना अब में तक आधे िसे भी क ... - The following `model_kwargs` a...
# Error processing: जानिए, ताजमहल से जुड़ी ये सच्चाई, जिससे अभी तक अंज... - The following `model_kwargs` a...
# Error processing: व्यक्ति -अरे हो गया... - The following `model_kwargs` a...
# Error processing: चेन्नई, 15फ रवर :े: अन्नाद्रमुकपा ्रमुख वी अदालत क... - The following `model_kwargs` a...
# Error processing: हालांकि उनकी तरफ़ से आई अधिकांश चिठ्ठियां हमें नही... - The following `model_kwargs` a...
# Error processing: जाने पंजाब जाने वाले ट्रेनों ने ने छोड़ा, रुड़की पूर... - The following `model_kwargs` a...
# Error processing: सुरक्षा लेकर अभी भी चिंतित भी है दंगा पीड़ित।... - The following `model_kwargs` a...
# Error processing: राफिन्हा का पिछला करार जून, 2016 को समाप्त हो रहा ... - The following `model_kwargs` a...
# Error processing: दमिश्क़ ने चेतावनी दी है कि अगर संयुक्त राष्ट्र सं... - The following `model_kwargs` a...
# Error processing: इस व्यवसथा से बरेलियंस को कफी राहत मिलेग। क्ंयकि द... - The following `model_kwargs` a...
# Error processing: पहली बार एक ही पोस्टर में दिखे अखिलेश-मायावती, गठब... - The following `model_kwargs` a...
# Error processing: फिर उन्होंने इसे अपनी के लिए इस्तेमाल किया।... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ उत्तराखंड ऋषिकेश फॉरेस्ट और किलर ब्यॉय... - The following `model_kwargs` a...
# Error processing: जीवन में धन अर्जित कर अपनी व्यक्ति 70 समस्याओं फीस... - The following `model_kwargs` a...
# Error processing: परंतु मेरे कॉलेज के पहले दिन में एक कमरे मे आराम क... - The following `model_kwargs` a...
# Error processing: कैमल्स के भी है सैलून... - The following `model_kwargs` a...
# Error processing: सलमान खान की फिल्म में आसिम रियाज की एंट्री? कभी ई... - The following `model_kwargs` a...
# Error processing: शनिवार सुबह ही गणखेतर महिला मंडल की सदस्य और अन्य ... - The following `model_kwargs` a...
# Error processing: वरिष्ठ खिलाड़ी ताकाओ सुजुकी को सिंगल्स में न खिलान... - The following `model_kwargs` a...
# Error processing: - आरोपियों में रिटायर्ड पुलिस ऑफिसर आलेहसन और पूर्... - The following `model_kwargs` a...
# Error processing: लंबेर ह खिच आंोदलन मद्देनजर के ही फैसला... - The following `model_kwargs` a...
# Error processing: थाना पुलिस जमुनापार द्वारा गाड़ी चेकिंग के दौरान भै... - The following `model_kwargs` a...
# Error processing: अ्ग्रगमाी स्मृतिलोप, coमlloquialy "बाहर रोग़न"क  र... - The following `model_kwargs` a...
# Error processing: द्ुनिया छोड़ गए ये 9 स्फटार्स, श्रीदवी से ज्यादा इ... - The following `model_kwargs` a...
# Error processing: परंपरागत के अलावा व्यवसायिक खेती की ओर किया किसानो... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ › मनोरंजन › फिल्म में काम करने के लिए ... - The following `model_kwargs` a...
# Error processing: सावधानी ही एड्स से बचाव : डा. शायना... - The following `model_kwargs` a...
# Error processing: सिवान के कगार तालाब खोने के कगार पर... - The following `model_kwargs` a...
# Error processing: महिलाओं ने भी दिखाई ताकत... - The following `model_kwargs` a...
# Error processing: हेल्थ वर्कर्स केयर का सफ्रश बंदक रजिस्टरेशन... - The following `model_kwargs` a...
# Error processing: इस नियम के अनुसार, अगर कोई बल्लेबाज शॉट मारता है औ... - The following `model_kwargs` a...
# Error processing: लोकमान्यताओं और हिंदू धर्म के विश्वास के आधार पर र... - The following `model_kwargs` a...
# Error processing: गैस की किल्लत... - The following `model_kwargs` a...
# Error processing: फेक करने प्रसारित वालों पर होगी कार्रवाई.. एसडीओ... - The following `model_kwargs` a...
# Error processing: - विश्व उन्हें स्वास्थ्य संगठन द्वारा सुझाई गई कई ... - The following `model_kwargs` a...
# Error processing: 4. जले पर मक्खन लगाना... - The following `model_kwargs` a...
# Error processing: उत्तराखडं पहुंचे गृहमंत्र ीअजमित शाह,ह वाई सर्वेक्... - The following `model_kwargs` a...
# Error processing: अतः मैं पाठकों से यही आग्रह करुंगी कि वह भी पर्याव... - The following `model_kwargs` a...
# Error processing: जिसमें जुलूस गोवर्धन के पूजनोत्सव अवसर चर्चा शोभाय... - The following `model_kwargs` a...
# Error processing: पसीने से तरबतर उसकी ज़बीन* है... - The following `model_kwargs` a...
# Error processing: ये तूफ़ान इस समय क्यूबा के पश्चिमी हिस्से से होकर ... - The following `model_kwargs` a...
# Error processing: मुख्यमंत्री कार्यालय के एक अधिकारी ने बताया कि बनर... - The following `model_kwargs` a...
# Error processing: के साये में राज्‍यपाल ने किया चाय और नाश्‍ता, मौसम... - The following `model_kwargs` a...
# Error processing: फिरजोाबद। मक्खनपुर मे प्तपनी के साथ हनद के यहां जा... - The following `model_kwargs` a...
# Error processing: बीएमओ होंगे जिम्मेदार... - The following `model_kwargs` a...
# Error processing: मैच काे 34वें ओवर में कुलदीप यादव नेे कपतना विलियस... - The following `model_kwargs` a...
# Error processing: 1.2 लीटर का पेट्रोल इंजन... - The following `model_kwargs` a...
# Error processing: दिनदहाड़े कास्मेटिक की ने में पिस्टल लेकर घुसा आगर... - The following `model_kwargs` a...
# Error processing: पीलीभीत,जेएनएनक े जिलााधकारी : खरे पुलकित े राष्ट्... - The following `model_kwargs` a...
# Error processing: हरदईो: ाक डीएम नयंा आदेश, से ADM SDM तक आंखों केय ... - The following `model_kwargs` a...
# Error processing: फैविपिराविर की कीमतों में शुरू हो गई जंग... - The following `model_kwargs` a...
# Error processing: उल्लेखनीय है कि भोजपुरी की सर्वाधिक फिल्मों में अभ... - The following `model_kwargs` a...
# Error processing: अटल मेमोयिल ेंय नूरमहल क्लब को 17 रन से शिकस्त... - The following `model_kwargs` a...
# Error processing: राजू जांगिड़/खेल डेस्क  | इंडियन प्रीमियर लीग के इत... - The following `model_kwargs` a...
# Error processing: उन्होंने अफगानिस्तान से अमेरिकी सैनिकों की पूरी तर... - The following `model_kwargs` a...
# Error processing: ड्यूटी दे रहे दो पुलिसकर्मियों को ऑडी ने मारी टक्क... - The following `model_kwargs` a...
# Error processing: तो इसके वजह से शारिरिक मेहनत घटा, वही दुसरी और लोग... - The following `model_kwargs` a...
# Error processing: शहीद के अंतिम संस्कार में उमड़ी भीड़, हैलिपेड पर दी ... - The following `model_kwargs` a...
# Error processing: Home > ख़बरें > देश ये > बीजेपी की ये खूबसूरत बीजेप... - The following `model_kwargs` a...
# Error processing: वे कभी राहलुग ांधी को अध्यक्ष बधनाने का बयान देते ... - The following `model_kwargs` a...
# Error processing: सर्किट हाउस के नजदीक सर्वोदय ग्रुप के सिटी ऑफिस के... - The following `model_kwargs` a...
# Error processing: स्लामािक स्टेट (आईएस) मेंज ाने से रोकनेप र सऊदी अ)... - The following `model_kwargs` a...
# Error processing: पालघर में हसाई प्ोरफइाल हुपक्ा बार पर छापा,प 43 लो... - The following `model_kwargs` a...
# Error processing: परंतु जिस प्रकार हम और पर्यावरण जुड़े हैं हमें पर्... - The following `model_kwargs` a...
# Error processing: उठती हुई पतंगों तरं गकी हो।।... - The following `model_kwargs` a...
# Error processing: यूरिन इंफेक्‍शन के लक्षण... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ › मनोरंजन › फिल्म में काम करने के लिए ... - The following `model_kwargs` a...
# Error processing: सावधानी ही एड्स से बचाव : डा. शायना... - The following `model_kwargs` a...
# Error processing: सिवान के कगार तालाब खोने के कगार पर... - The following `model_kwargs` a...
# Error processing: महिलाओं ने भी दिखाई ताकत... - The following `model_kwargs` a...
# Error processing: हेल्थ वर्कर्स केयर का सफ्रश बंदक रजिस्टरेशन... - The following `model_kwargs` a...
# Error processing: इस नियम के अनुसार, अगर कोई बल्लेबाज शॉट मारता है औ... - The following `model_kwargs` a...
# Error processing: लोकमान्यताओं और हिंदू धर्म के विश्वास के आधार पर र... - The following `model_kwargs` a...
# Error processing: गैस की किल्लत... - The following `model_kwargs` a...
# Error processing: फेक करने प्रसारित वालों पर होगी कार्रवाई.. एसडीओ... - The following `model_kwargs` a...
# Error processing: - विश्व उन्हें स्वास्थ्य संगठन द्वारा सुझाई गई कई ... - The following `model_kwargs` a...
# Error processing: 4. जले पर मक्खन लगाना... - The following `model_kwargs` a...
# Error processing: उत्तराखडं पहुंचे गृहमंत्र ीअजमित शाह,ह वाई सर्वेक्... - The following `model_kwargs` a...
# Error processing: अतः मैं पाठकों से यही आग्रह करुंगी कि वह भी पर्याव... - The following `model_kwargs` a...
# Error processing: जिसमें जुलूस गोवर्धन के पूजनोत्सव अवसर चर्चा शोभाय... - The following `model_kwargs` a...
# Error processing: पसीने से तरबतर उसकी ज़बीन* है... - The following `model_kwargs` a...
# Error processing: ये तूफ़ान इस समय क्यूबा के पश्चिमी हिस्से से होकर ... - The following `model_kwargs` a...
# Error processing: मुख्यमंत्री कार्यालय के एक अधिकारी ने बताया कि बनर... - The following `model_kwargs` a...
# Error processing: के साये में राज्‍यपाल ने किया चाय और नाश्‍ता, मौसम... - The following `model_kwargs` a...
# Error processing: फिरजोाबद। मक्खनपुर मे प्तपनी के साथ हनद के यहां जा... - The following `model_kwargs` a...
# Error processing: बीएमओ होंगे जिम्मेदार... - The following `model_kwargs` a...
# Error processing: मैच काे 34वें ओवर में कुलदीप यादव नेे कपतना विलियस... - The following `model_kwargs` a...
# Error processing: 1.2 लीटर का पेट्रोल इंजन... - The following `model_kwargs` a...
# Error processing: दिनदहाड़े कास्मेटिक की ने में पिस्टल लेकर घुसा आगर... - The following `model_kwargs` a...
# Error processing: पीलीभीत,जेएनएनक े जिलााधकारी : खरे पुलकित े राष्ट्... - The following `model_kwargs` a...
# Error processing: हरदईो: ाक डीएम नयंा आदेश, से ADM SDM तक आंखों केय ... - The following `model_kwargs` a...
# Error processing: फैविपिराविर की कीमतों में शुरू हो गई जंग... - The following `model_kwargs` a...
# Error processing: उल्लेखनीय है कि भोजपुरी की सर्वाधिक फिल्मों में अभ... - The following `model_kwargs` a...
# Error processing: अटल मेमोयिल ेंय नूरमहल क्लब को 17 रन से शिकस्त... - The following `model_kwargs` a...
# Error processing: राजू जांगिड़/खेल डेस्क  | इंडियन प्रीमियर लीग के इत... - The following `model_kwargs` a...
# Error processing: उन्होंने अफगानिस्तान से अमेरिकी सैनिकों की पूरी तर... - The following `model_kwargs` a...
# Error processing: ड्यूटी दे रहे दो पुलिसकर्मियों को ऑडी ने मारी टक्क... - The following `model_kwargs` a...
# Error processing: तो इसके वजह से शारिरिक मेहनत घटा, वही दुसरी और लोग... - The following `model_kwargs` a...
# Error processing: शहीद के अंतिम संस्कार में उमड़ी भीड़, हैलिपेड पर दी ... - The following `model_kwargs` a...
# Error processing: Home > ख़बरें > देश ये > बीजेपी की ये खूबसूरत बीजेप... - The following `model_kwargs` a...
# Error processing: वे कभी राहलुग ांधी को अध्यक्ष बधनाने का बयान देते ... - The following `model_kwargs` a...
# Error processing: सर्किट हाउस के नजदीक सर्वोदय ग्रुप के सिटी ऑफिस के... - The following `model_kwargs` a...
# Error processing: स्लामािक स्टेट (आईएस) मेंज ाने से रोकनेप र सऊदी अ)... - The following `model_kwargs` a...
# Error processing: पालघर में हसाई प्ोरफइाल हुपक्ा बार पर छापा,प 43 लो... - The following `model_kwargs` a...
# Error processing: परंतु जिस प्रकार हम और पर्यावरण जुड़े हैं हमें पर्... - The following `model_kwargs` a...
# Error processing: उठती हुई पतंगों तरं गकी हो।।... - The following `model_kwargs` a...
# Error processing: यूरिन इंफेक्‍शन के लक्षण... - The following `model_kwargs` a...
# Generating corrections:  82%|████████▏ | 9/11 [00:00<00:00, 13.62it/s]
# Error processing: बेटकप ो झुलसता देख पिता बसंत उसे बचने प्रयास करने ... - The following `model_kwargs` a...
# Error processing: गांवोंम ें चुनाी चललस, मनुहार में जुटे ्रत्याशी... - The following `model_kwargs` a...
# Error processing: जिले की नगर पंचायत कछौना पतसेनी व माधौगंज को बुधवा... - The following `model_kwargs` a...
# Error processing: मोदी के नेतृ्व में भारत सरकार का जमम्-ूकश्मीरप र ख... - The following `model_kwargs` a...
# Error processing: अफगानितस्‍तान में लोकतांत्रिक लोकतंत्र पर भरोसा मज... - The following `model_kwargs` a...
# Error processing: ताड़का उन राक्षसों में सबसे अधिक भयंकर तथा विनाशका... - The following `model_kwargs` a...
# Error processing: वार्ड नौ : नौ दिनों से पानी से घिरे हैं लोग... - The following `model_kwargs` a...
# Error processing: खाताधारक को डराकर पूछ लिया अकाउंट नंबर और पिन, फिर... - The following `model_kwargs` a...
# Error processing: ये भी पढ़ें:-  BSNL का यूजर्स को तोहफा, 30 नहीं अब ... - The following `model_kwargs` a...
# Error processing: िल्ली के और आम आादमी पर्टी केउ ्ंयोजक अकरविंद ने ए... - The following `model_kwargs` a...
# Error processing: अब बाएं पैर को घुटने से मोड़ें और उसके तलवे को दाई... - The following `model_kwargs` a...
# Error processing: विज्ञान किसी भी चीज को तर्क और तथ्य के आधार पर समझ... - The following `model_kwargs` a...
# Error processing: बाबरी मस्जिद एक्शन कमेटी के ज़फ़रयाब जिलानी ने कहा... - The following `model_kwargs` a...
# Error processing: ाजरी है नियुक्ति ी मांग मांग... - The following `model_kwargs` a...
# Error processing: अंतर्गत सगरा ग्राम सथनी निवासी ओपी की ग्राम नवब्या... - The following `model_kwargs` a...
# Error processing: मिले चार साल की छूट का फायदा... - The following `model_kwargs` a...
# Error processing: बिना के अनुमत काटकर जा रहे चालक को रोकना वन बट को ... - The following `model_kwargs` a...
# Error processing: एमजीएम कॉलेज के डाक्टरों की देखरेख में सोमवार को 1... - The following `model_kwargs` a...
# Error processing: जिप्सी समेत 3 गिरफ्तार, पुलिस नहीं कर रही पुष्टि... - The following `model_kwargs` a...
# Error processing: जािए कैसे हटोा बच्चों का टीकाकरण... - The following `model_kwargs` a...
# Error processing: नई दिल्ली. देश विरोधी नारेबाजी के आरोपी कन्हैया कु... - The following `model_kwargs` a...
# Error processing: राशि सिंहः वाले लोगों और के लिए धनतेरस कपड़ों पर क... - The following `model_kwargs` a...
# Error processing: अमीर, गरीब देशों के बीच की खाई से जूझ रहा जलवायु श... - The following `model_kwargs` a...
# Error processing: प्रेमी के साथ रची साजिश... - The following `model_kwargs` a...
# Error processing: नेटफ्लिक्स की सीरीज में समाज के अलग-अलग तबके की पा... - The following `model_kwargs` a...
# Error processing: इंडियन मेडिकल एसोसिएशन के डॉक्टर के के अग्रवाल के ... - The following `model_kwargs` a...
# Error processing: त्यौहारी सीजन में बिना नोटिस नल कनेक्शन काट रहा आर... - The following `model_kwargs` a...
# Error processing: पीटीईआ कार्यकर्ता के घरप र है लड़कडी... - The following `model_kwargs` a...
# Error processing: ट्रेलर का अभी ही टमे ंरिीज किया गया हैर और ्रेलर इ... - The following `model_kwargs` a...
# Error processing: थाने में लड़की से मिलने आए चाचा ने किया लड़की पर ह... - The following `model_kwargs` a...
# Error processing: -स्कूल, कॉलेज, कार्यालय में लोगों को जीका वायरस के... - The following `model_kwargs` a...
# Error processing: इंस्टाग्राफ पर पोस्ट की फोटो... - The following `model_kwargs` a...
# Error processing: सूरत में नोटबंद ा विरोध करेंगे राुहल गंी, व्यापािर... - The following `model_kwargs` a...
# Error processing: बीजेपी के साथ गठबंधन पर क्या बोले पार्टी के नेता... - The following `model_kwargs` a...
# Error processing: 4- होम लोन पर चुकाया जाने वाला ब्याज... - The following `model_kwargs` a...
# Error processing: कस्बे के लोग दिन में बंदर और रात में कुत्तों के आत... - The following `model_kwargs` a...
# Error processing: इलेक्ट्रिक फेंसिंग भी है दर्दनाक यातना... - The following `model_kwargs` a...
# Error processing: दुनिया का सबसे ऊचांई वाली ब्रीज जिसकी उचाई 110 मंज... - The following `model_kwargs` a...
# Error processing: सीटें शादार... - The following `model_kwargs` a...
# Error processing: जुनावई: दो बाइक की आमने-सामने से हुई भिड़ंत में एक ... - The following `model_kwargs` a...
# Error processing: लेखभारीय रेलवे मे हजार 2 0वेक्‍सी की बढ़ोतरी, में ... - The following `model_kwargs` a...
# Error processing: सबरीमाला मंदरि (इनसेट- कनकदुर्गःा, ोफोटोःस ोशल ीडि... - The following `model_kwargs` a...
# Error processing: भारत और चीन के बीच अंतरराष्ट्रीय सीमा पर विवाद के ... - The following `model_kwargs` a...
# Error processing: इस पर सपा अध्यक्ष अखिलेश यादव ने पलटवार करते हुए क... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ देश 'शूटर दादी' चंद्रो तोमर को हुआ कोर... - The following `model_kwargs` a...
# Error processing: अलग-अलग तिथियों में आदिवासी समाज धूमधाम से मनाएगा ... - The following `model_kwargs` a...
# Error processing: तो हमारी मां ने पत्र यद करके और उसके बाद उसे देखे ... - The following `model_kwargs` a...
# Error processing: राजधानी में पहले हिंदू मंदिर के निर्माण को चुनौती ... - The following `model_kwargs` a...
# Error processing: टरं्किश कंज्य‍ूमर ीइले्क‍टॉनिक ंपनी वेस्‍टल ने पिछ... - The following `model_kwargs` a...
# Error processing: रात के खाने और सोने के समय में कम से कम से 3 घंटे ... - The following `model_kwargs` a...
# Error processing: पान का - खुद सेव क ोहाइड्रे रखं. प्रितदिन लगडभग 10... - The following `model_kwargs` a...
# ...
# Error processing: अरुणाचल: वायुसेना कवा एक 2 से लापता मामल ाअरुणाचल ... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ उत्तर प्रदेश गाजीपुर सरकारी बीज गोदाम ... - The following `model_kwargs` a...
# Error processing: इसे भी पढ़ेंः सुप्रीम कोर्ट पढ़ेंः कांग्रेस पढ़ेंः... - The following `model_kwargs` a...
# Error processing: ! ‘रिवेंज ‘पॉर्न’ अबह होगी कड़ीस ज़ा... - The following `model_kwargs` a...
# Error processing: न्यायिक बुनियादी ढांचे पर, सीजेआई ने कहा कि उन्हों... - The following `model_kwargs` a...
# Error processing: किसी भी कार्य को सीख लेने की क्रिया को शिक्षा कहा ... - The following `model_kwargs` a...
# Error processing: 12 फरवर  :जनपहचान0 60 रुपएा साल की पुष्पा पत्न ीरा... - The following `model_kwargs` a...
# Error processing: छत्तीसगढ़ समाचार : मनरेगा में गड़बड़ी पर ग्रामीण विभा... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ झारखंड जमशेदपुर ट्रांसफॉर्मर चोरी मामल... - The following `model_kwargs` a...
# Error processing: लुइ ने 34 गेंद पर 79 नर बनाए... - The following `model_kwargs` a...
# Error processing: परिवार ने लगाई मदद की गुहार... - The following `model_kwargs` a...
# Error processing: इस लुक में ड्रेस के साथ साक्षी की एक्सेसरीज काफी ब... - The following `model_kwargs` a...
# Error processing: किन ग्राहकों पर असर... - The following `model_kwargs` a...
# Error processing: प्रदर्शनकारियों को मेरठ पुलिस ने पाकिस्तान चले जान... - The following `model_kwargs` a...
# Error processing: मुझे लगता है कि व्यक्ति को जीवन में हर प्रकार के ख... - The following `model_kwargs` a...
# Error processing: वहा जाकर उसने पुरी कहानि उनको सुनाई तो रावण आग बबू... - The following `model_kwargs` a...
# Error processing: मौत िअविवािहत गर्भवती ने वौिियो विडियो ेखकर किाया ... - The following `model_kwargs` a...
# Error processing: ये भी पढ़ें :  मंदसौर के बाद भोपाल में भारी उपद्रव... - The following `model_kwargs` a...
# Error processing: भारतीय उद्योग परिसंघ (सीआईआई) की मध्य प्रदेश शाखा ... - The following `model_kwargs` a...
# Error processing: हम करने बात जा रहे हैं हैं उन सभी (बल्लेबाजी, विभा... - The following `model_kwargs` a...
# Error processing: हिंदी न्यूज़ उत्तराखंड अल्मोड़ा महाविद्यालय में एसि... - The following `model_kwargs` a...
# Error processing: िंदी न्यूज़ › ने नउ्तर लखनऊ प्रदेश › ीवपी सिंह ने फ... - The following `model_kwargs` a...
# Error processing: सर्वेक्षण के अनुसार, “इंटरनेट की चाहत इतनी बढ़ गई ... - The following `model_kwargs` a...
# Error processing: भी ये पढ़े: इस ग्रुप को IPL मिला टाइटल स्पॉन्सर... - The following `model_kwargs` a...
# Error processing: जयपुर। मुख्यमंत्री वसुंधरा राजे ने शनिवार को अपने ... - The following `model_kwargs` a...
# Error processing: बस एक लें, आधा काट लें. लें, उनमें से हर से एक थोड... - The following `model_kwargs` a...
# Error processing: दवे ने कमहहा, ‘किताब तथ्यत्मक विवण से भरी पड़ी है.... - The following `model_kwargs` a...
# Error processing: वाराणसी में कोरोना से जान कोरोना वालों का गंवाने क... - The following `model_kwargs` a...
# Error processing: सन 2019 के अंत में कोरोना की आगमन ने जो लोकडाउन लग... - The following `model_kwargs` a...
# Error processing: ज्ञापन में में ये भी बताया... - The following `model_kwargs` a...
# Error processing: इसमें कोई दौहराई नहीं है कि आज से 15 20 वर्ष पूर्व... - The following `model_kwargs` a...
# Error processing: फ़ाकलैंड क ायुद्ध... - The following `model_kwargs` a...
# Error processing: गूगल के लिए काम करने वाले तीसरे पक्ष यानी  कॉन्ट्र... - The following `model_kwargs` a...
# Error processing: इसी के चलते काफी सारी संख्या एक ही जैसी चीज करने ल... - The following `model_kwargs` a...
# Error processing: संविदा पर तैनात र्किमयों को रुपया 400 प्रतिदिन की ... - The following `model_kwargs` a...
# Error processing: करछों, तहसील जोशठीमठ... - The following `model_kwargs` a...
# Error processing: महिलाओं के जरिये "मिशन कश्मीर" पर IS... - The following `model_kwargs` a...
# Error processing: नानक पिता को एक चाहते थे, लेकिन नियति को तो और ही ... - The following `model_kwargs` a...
# Error processing: इंजीनियरिंग छत्ोरं े किया फर्जीवाड़ा... - The following `model_kwargs` a...
# Error processing: 8 दिसंबर को 'भारत बंद' का कितना होगा असर... - The following `model_kwargs` a...
# Error processing: महें ऐसी कोई सूचना नही ंदी ग। यि इस रह की कोई घटना... - The following `model_kwargs` a...
# Error processing: कईय तैनाती के लिए हुएक ार्मयुक्त... - The following `model_kwargs` a...
# Error processing: बड़ी पहलवान खबर: पहलवान पहलवान दत्त योगेश्वर बीजेपी... - The following `model_kwargs` a...
# Error processing: पीएम ने कहा कि इस ऑपरेशन की कामयाबी या नाकामी से ज... - The following `model_kwargs` a...
# Error processing: उन्होंने आप के निलंबित सदस्य मुनीश रायजादा द्वारा ... - The following `model_kwargs` a...
# Error processing: सत्ता बदलने के बाद भी नहीं बदले हालात, नकल माफियाओ... - The following `model_kwargs` a...
# Error processing: बाहर के आइट्म्स का उपयोग न करके घर के बने भोजन का ... - The following `model_kwargs` a...
# Error processing: नगर के थानाध्यक्ष मुखिया व आश्वासन के के बाद सड़क स... - The following `model_kwargs` a...
# Error processing: श्रीकांत वर्मा मार्ग में छाया अंधेरा... - The following `model_kwargs` a...
# Error processing: भारीत यजनता पार्टी ओबीसी मोर्चा की बपैठजक जिलाधय्क... - The following `model_kwargs` a...
# Error processing: व जयपुर कोटा समेत में हजा र10 लोगों से की थी 10 कर... - The following `model_kwargs` a...
# Error processing: मुज़फ्फरपुर के साथ बिहार के सुप्रीम शेल्टर 17 होम क... - The following `model_kwargs` a...
# Error processing: AN-32 को खोजने के लिए ग्लोबल 5000 सर्विलांस एयरक्र... - The following `model_kwargs` a...
# Error processing: एक राजा लोकप्रियता एवं राज्य उसके क्षेत्र तक सीमित... - The following `model_kwargs` a...
# Error processing: दावों के बीच दिल्ली... - The following `model_kwargs` a...
# Error processing: सेब सीजन में मंडियों में तैनात होगा पुलिस बल... - The following `model_kwargs` a...
# Error processing: जोगी केांग्रेस के आक्रामक आक्राम करूखे न ेबदला... - The following `model_kwargs` a...
# Error processing: एक तो यह कि जब मुसावी ने अपराध किया तब उनकी उम्र 1... - The following `model_kwargs` a...
# Error processing: उन्होंने कहा कि बिना मास्क के घूमते पाये गये लोगों... - The following `model_kwargs` a...
# Error processing: हरियाणा के एवं एवं बाल विकास विभाग परिस्थितियों...... - The following `model_kwargs` a...
# Error processing: ऐसी कुछ घटनाएं हुई थी मेरे जीवन में, और सच कुछ कहू... - The following `model_kwargs` a...
# Error processing: युवक की दिया कर गया गया था हादसे का रूप... - The following `model_kwargs` a...
# Error processing: उर्वशी ढोलकिया यानि पिछली कोमोलिका से तुलना होने प... - The following `model_kwargs` a...
# Error processing: कप्तान टिम पेन के साथ का मनातेकह ुए पैट सेाथ कमिंस... - The following `model_kwargs` a...
# Error processing: हिसार जिले के बालक गांव में एक स्कूल के क्लास में ... - The following `model_kwargs` a...
# Error processing: यशस्वी जायसवाल को उनके बैट पर एमएस धोनी का ऑटोग्रा... - The following `model_kwargs` a...
# Error processing: सभी के घरों में पूजा पाठ दिवाली के दिन हुआ प्रारम्... - The following `model_kwargs` a...
# Error processing: जापानी महिला के साथ यौ नशोषण करेन वाला हबाबा गिर्त... - The following `model_kwargs` a...
# Error processing: तेंदुए दहशत गणेश नगर कॉलोनी में स्थाी यनिवासी निवा... - The following `model_kwargs` a...
# Error processing: इन सब चीजों से बचने का सबसे सरल इलाज है सबको शिक्ष... - The following `model_kwargs` a...
# Error processing: मेने Cristiano से कई सिख ली है जिससे मुझे मेरे जीव... - The following `model_kwargs` a...
# Error processing: 2 बैल की भी की मौत... - The following `model_kwargs` a...
# Error processing: फॉरेंसिक मानवविज्ञान मे अवशेष की पहचान करना और उसे... - The following `model_kwargs` a...
# Error processing: समझौतो में पिसती बेचारी... - The following `model_kwargs` a...
# Error processing: छात्रों को मिलेगी मदद... - The following `model_kwargs` a...
# Error processing: 2020ब ारदाचट्टी े चुनाव में अर्जु्न भुइयां (IND) क... - The following `model_kwargs` a...
# Error processing: स्कूील िक्षक के जज्बे को सलाम, ेलॉकडाउन मेंो बचच्ो... - The following `model_kwargs` a...
# Error processing: इस बीच, शिवम के दोस्त गोविंद शर्मा ने संवाददाताओं ... - The following `model_kwargs` a...
# Error processing: कोविड जांच कराने के पर भी रेल यात्री कतराते हैं। ज... - The following `model_kwargs` a...
# Error processing: आउडसाइडर की तरह ऑडिशन देने के लिए तैयार हूं: सारा ... - The following `model_kwargs` a...
# Error processing: पटना से अगवा बच्चे को रायपुर में बंधक बनाने का माम... - The following `model_kwargs` a...
# Error processing: नुक्कड़ का नाटक से दिया वनाग्नि सुरक्षा का संदेश न... - The following `model_kwargs` a...
# Error processing: सोशल मिडिया से लोगो में बड़ा बदलाव नजर आने लगा हैं... - The following `model_kwargs` a...
# Error processing: परीक्षा से पहले जेईई मेन की परं्षाएं भी ्थगितद ी ग... - The following `model_kwargs` a...
# Error processing: फ़ाकलैंड क ायुद्ध... - The following `model_kwargs` a...
# Error processing: गूगल के लिए काम करने वाले तीसरे पक्ष यानी  कॉन्ट्र... - The following `model_kwargs` a...
# Error processing: इसी के चलते काफी सारी संख्या एक ही जैसी चीज करने ल... - The following `model_kwargs` a...
# Error processing: संविदा पर तैनात र्किमयों को रुपया 400 प्रतिदिन की ... - The following `model_kwargs` a...
# Error processing: करछों, तहसील जोशठीमठ... - The following `model_kwargs` a...
# Error processing: महिलाओं के जरिये "मिशन कश्मीर" पर IS... - The following `model_kwargs` a...
# Error processing: नानक पिता को एक चाहते थे, लेकिन नियति को तो और ही ... - The following `model_kwargs` a...
# Error processing: इंजीनियरिंग छत्ोरं े किया फर्जीवाड़ा... - The following `model_kwargs` a...
# Error processing: 8 दिसंबर को 'भारत बंद' का कितना होगा असर... - The following `model_kwargs` a...
# Error processing: महें ऐसी कोई सूचना नही ंदी ग। यि इस रह की कोई घटना... - The following `model_kwargs` a...
# Error processing: कईय तैनाती के लिए हुएक ार्मयुक्त... - The following `model_kwargs` a...
# Error processing: बड़ी पहलवान खबर: पहलवान पहलवान दत्त योगेश्वर बीजेपी... - The following `model_kwargs` a...
# Error processing: पीएम ने कहा कि इस ऑपरेशन की कामयाबी या नाकामी से ज... - The following `model_kwargs` a...
# Error processing: उन्होंने आप के निलंबित सदस्य मुनीश रायजादा द्वारा ... - The following `model_kwargs` a...
# Error processing: सत्ता बदलने के बाद भी नहीं बदले हालात, नकल माफियाओ... - The following `model_kwargs` a...
# Error processing: बाहर के आइट्म्स का उपयोग न करके घर के बने भोजन का ... - The following `model_kwargs` a...
# Error processing: नगर के थानाध्यक्ष मुखिया व आश्वासन के के बाद सड़क स... - The following `model_kwargs` a...
# Error processing: श्रीकांत वर्मा मार्ग में छाया अंधेरा... - The following `model_kwargs` a...
# Error processing: भारीत यजनता पार्टी ओबीसी मोर्चा की बपैठजक जिलाधय्क... - The following `model_kwargs` a...
# Error processing: व जयपुर कोटा समेत में हजा र10 लोगों से की थी 10 कर... - The following `model_kwargs` a...
# Error processing: मुज़फ्फरपुर के साथ बिहार के सुप्रीम शेल्टर 17 होम क... - The following `model_kwargs` a...
# Error processing: AN-32 को खोजने के लिए ग्लोबल 5000 सर्विलांस एयरक्र... - The following `model_kwargs` a...
# Error processing: एक राजा लोकप्रियता एवं राज्य उसके क्षेत्र तक सीमित... - The following `model_kwargs` a...
# Error processing: दावों के बीच दिल्ली... - The following `model_kwargs` a...
# Error processing: सेब सीजन में मंडियों में तैनात होगा पुलिस बल... - The following `model_kwargs` a...
# Error processing: जोगी केांग्रेस के आक्रामक आक्राम करूखे न ेबदला... - The following `model_kwargs` a...
# Error processing: एक तो यह कि जब मुसावी ने अपराध किया तब उनकी उम्र 1... - The following `model_kwargs` a...
# Error processing: उन्होंने कहा कि बिना मास्क के घूमते पाये गये लोगों... - The following `model_kwargs` a...
# Error processing: हरियाणा के एवं एवं बाल विकास विभाग परिस्थितियों...... - The following `model_kwargs` a...
# Error processing: ऐसी कुछ घटनाएं हुई थी मेरे जीवन में, और सच कुछ कहू... - The following `model_kwargs` a...
# Error processing: युवक की दिया कर गया गया था हादसे का रूप... - The following `model_kwargs` a...
# Error processing: उर्वशी ढोलकिया यानि पिछली कोमोलिका से तुलना होने प... - The following `model_kwargs` a...
# Error processing: कप्तान टिम पेन के साथ का मनातेकह ुए पैट सेाथ कमिंस... - The following `model_kwargs` a...
# Error processing: हिसार जिले के बालक गांव में एक स्कूल के क्लास में ... - The following `model_kwargs` a...
# Error processing: यशस्वी जायसवाल को उनके बैट पर एमएस धोनी का ऑटोग्रा... - The following `model_kwargs` a...
# Error processing: सभी के घरों में पूजा पाठ दिवाली के दिन हुआ प्रारम्... - The following `model_kwargs` a...
# Error processing: जापानी महिला के साथ यौ नशोषण करेन वाला हबाबा गिर्त... - The following `model_kwargs` a...
# Error processing: तेंदुए दहशत गणेश नगर कॉलोनी में स्थाी यनिवासी निवा... - The following `model_kwargs` a...
# Error processing: इन सब चीजों से बचने का सबसे सरल इलाज है सबको शिक्ष... - The following `model_kwargs` a...
# Error processing: मेने Cristiano से कई सिख ली है जिससे मुझे मेरे जीव... - The following `model_kwargs` a...
# Error processing: 2 बैल की भी की मौत... - The following `model_kwargs` a...
# Error processing: फॉरेंसिक मानवविज्ञान मे अवशेष की पहचान करना और उसे... - The following `model_kwargs` a...
# Error processing: समझौतो में पिसती बेचारी... - The following `model_kwargs` a...
# Error processing: छात्रों को मिलेगी मदद... - The following `model_kwargs` a...
# Error processing: 2020ब ारदाचट्टी े चुनाव में अर्जु्न भुइयां (IND) क... - The following `model_kwargs` a...
# Error processing: स्कूील िक्षक के जज्बे को सलाम, ेलॉकडाउन मेंो बचच्ो... - The following `model_kwargs` a...
# Error processing: इस बीच, शिवम के दोस्त गोविंद शर्मा ने संवाददाताओं ... - The following `model_kwargs` a...
# Error processing: कोविड जांच कराने के पर भी रेल यात्री कतराते हैं। ज... - The following `model_kwargs` a...
# Error processing: आउडसाइडर की तरह ऑडिशन देने के लिए तैयार हूं: सारा ... - The following `model_kwargs` a...
# Error processing: पटना से अगवा बच्चे को रायपुर में बंधक बनाने का माम... - The following `model_kwargs` a...
# Error processing: नुक्कड़ का नाटक से दिया वनाग्नि सुरक्षा का संदेश न... - The following `model_kwargs` a...
# Error processing: सोशल मिडिया से लोगो में बड़ा बदलाव नजर आने लगा हैं... - The following `model_kwargs` a...
# Error processing: परीक्षा से पहले जेईई मेन की परं्षाएं भी ्थगितद ी ग... - The following `model_kwargs` a...
# Generating corrections: 100%|██████████| 11/11 [00:00<00:00, 12.15it/s]
# Generated 527 corrections
#
# Calculating evaluation metrics...
#
# EVALUATION RESULTS:
# ========================================
# Dataset Statistics:
#    Total samples: 527
#    Need correction: 283 (53.7%)
#    Perfect (no change needed): 244
#
# Model Performance:
#    Exact match accuracy: 46.3% (244/527)
#    Changes made: 0 (0.0%)
#    Correct changes: 0
#
# Correction Metrics:
#    Precision: 0.0% (correct changes / total changes)
#    Recall: 0.0% (correct changes / needed changes)
#    F1-Score: 0.0%
#
# Sample Results:
# --------------------------------------------------------------------------------
# Failed Corrections (showing first 3):
#    1. Original: यह भी पढ़ें  सेहत के लि एजरूरी है रो स्नान करना।
#       Reference: यह भी पढ़ें - सेहत के लिए जरूरी है रोज स्नान करना।
#       Predicted: यह भी पढ़ें  सेहत के लि एजरूरी है रो स्नान करना।
#
#    2. Original: शमा को बीजेप् ीने प्रचारकों का शेाड्यूल जारसी का है दिया इसके मुताबकिप ्रधानमंत्री नरेंद्र मोदी हरिैयाणाै में चार रैलियाकं
#       Reference: #रविवार शाम को बीजेपी ने स्टार प्रचारकों का शेड्यूल जारी कर दिया है. इसके मुताबिक प्रधानमंत्री नरेंद्र मोदी हरियाणा में चार रैलियां करेंगे.
#       Predicted: शमा को बीजेप् ीने प्रचारकों का शेाड्यूल जारसी का है दिया इसके मुताबकिप ्रधानमंत्री नरेंद्र मोदी हरिैयाणाै में चार रैलियाकं
#
#    3. Original: नमेरे 'ऐ वतन के गाना लोगों' लता ज ीन ेकेa ेहरू लिएग गाया, लगत जनकारी दे टरोल हुए डडलानी | Filmymantra
#       Reference: ﻿ 'ऐ मेरे वतन के लोगों' गाना लता जी ने नेहरू के लिए गाया, गलत जानकारी दे ट्रोल हुए विशाल डडलानी | Filmymantra
#       Predicted: नमेरे 'ऐ वतन के गाना लोगों' लता ज ीन ेकेa ेहरू लिएग गाया, लगत जनकारी दे टरोल हुए डडलानी | Filmymantra
#
# Evaluation completed!
# Evaluation results saved to ./indicbart-hindi-final/evaluation_results.json

# %%
# Summary and next steps
print(f"INDICBART HINDI TRAINING COMPLETE!")
print(f"="*60)

print(f"\nTraining Summary:")
if 'training_results' in globals():
    print(f"   Training completed successfully")
    print(f"   Final training loss: {training_results.training_loss:.4f}")
    print(f"   Training time: {training_results.metrics.get('train_runtime', 0):.1f} seconds")
else:
    print(f"   Training results not available")

if 'final_eval_results' in globals():
    print(f"   Final eval loss: {final_eval_results['eval_loss']:.4f}")
    print(f"   Eval samples/sec: {final_eval_results['eval_samples_per_second']:.1f}")

print(f"\nModel Performance:")
if 'evaluation_results' in globals():
    results = evaluation_results
    print(f"   Exact Match: {results['exact_match_accuracy']:.1f}%")
    print(f"   F1-Score: {results['f1_score']:.1f}%")
    print(f"   Precision: {results['precision']:.1f}%")
    print(f"   Recall: {results['recall']:.1f}%")
    print(f"   Change Rate: {results['change_rate']:.1f}%")

print(f"\nModel Files:")
output_dir = Path(CONFIG['output_dir'])
if output_dir.exists():
    model_files = list(output_dir.glob('*'))
    for file in sorted(model_files):
        size_mb = file.stat().st_size / (1024**2) if file.is_file() else 0
        file_type = "DIR" if file.is_dir() else "FILE"
        print(f"   {file_type}: {file.name} {'(' + str(size_mb) + ' MB)' if file.is_file() and size_mb > 0.1 else ''}")

print(f"\nUsage:")
print(f"   Model saved to: {CONFIG['output_dir']}")
print(f"   Use function: correct_hindi_grammar('your sentence here')")
print(f"   Example: correct_hindi_grammar('मैं कल दिल्ली जाऊगा')")

print(f"\nNext Steps:")
print(f"   1. Test on more examples")
print(f"   2. Deploy the model for inference")
print(f"   3. Integrate with your error classification system")
print(f"   4. Consider fine-tuning on domain-specific data")

print(f"\nReady for Hindi Grammar Correction!")

# Final test
print(f"\nFinal Test:")
test_input = "मैं कल दिल्ली जाऊगा"
try:
    test_output = correct_hindi_grammar(test_input)
    print(f"   Input: {test_input}")
    print(f"   Output: {test_output}")
    print(f"   Status: {'Corrected' if test_input != test_output else 'Unchanged'}")
except Exception as e:
    print(f"   Test failed: {str(e)}")
